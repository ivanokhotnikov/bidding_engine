# %% [markdown]
# # <a id='toc1_'></a>[Forecasting (PyTorch)](#toc0_)

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Forecasting (PyTorch)](#toc1_)
#   - [Bidding dataset class](#toc1_1_)
#   - [LSTM model class](#toc1_2_)
#   - [Early stopping class](#toc1_3_)
#   - [Experiment class](#toc1_4_)
#   - [Parameters](#toc1_5_)
#   - [Model](#toc1_6_)
#   - [Training](#toc1_7_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
import json
import os

import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, Dataset

# %% [markdown]
# ## <a id='toc1_1_'></a>[Bidding dataset class](#toc0_)

# %%
class BiddingData(Dataset):

    def __init__(self,
                 seq_len: int,
                 pred_len: int,
                 scale: bool,
                 flag: str,
                 val_split: float,
                 test_split: float,
                 cluster: int,
                 features: list,
                 target: str | None = None) -> None:
        assert flag in ['train', 'test', 'val', 'pred']
        assert target
        assert features
        self.flag = flag
        type_map = {'train': 0, 'val': 1, 'test': 2}
        self.set_type = type_map[self.flag]
        self.seq_len = seq_len
        self.pred_len = pred_len
        self.val_split = val_split
        self.test_split = test_split
        self.target = target
        self.features = features
        self.scale = scale
        self.cluster = cluster
        self.__read_data__()

    def __len__(self) -> int:
        return len(self.x) - self.seq_len - self.pred_len + 1

    def __read_data__(self) -> pd.DataFrame:
        cluster_df = pd.read_csv(
            os.path.join(os.environ['PROCESSED_DATA_PATH'],
                         f'processed_{self.cluster}.csv'))
        size = len(cluster_df)
        border1s = [
            0,
            int(size * (1 - self.val_split - self.test_split)),
            int(size * (1 - self.test_split))
        ]
        border2s = [
            int(size * (1 - self.val_split - self.test_split)),
            int(size * (1 - self.test_split)), size
        ]
        border1 = border1s[self.set_type]
        border2 = border2s[self.set_type]
        self.forecast_features = cluster_df.columns
        self.dataset = cluster_df.loc[border1:border2, features + [target]]
        self.data = self.dataset.values
        self.y = cluster_df.loc[border1:border2,
                                self.target].values.reshape(-1, 1)
        self.x = cluster_df.loc[border1:border2, self.features].values

        if self.scale:
            self.scaler = StandardScaler()
            train_data = cluster_df.loc[border1s[0]:border2s[0],
                                        features + [target]]
            self.scaler.fit(train_data)
            self.data = self.scaler.transform(self.dataset.values)
            self.x = pd.DataFrame(data=self.data,
                                  columns=features + [target])[features].values
            self.y = pd.DataFrame(data=self.data, columns=features +
                                  [target])[target].values.reshape(-1, 1)

    def __getitem__(self, index: int):
        x_begin = index
        x_end = x_begin + self.seq_len
        y_begin = x_end
        y_end = y_begin + self.pred_len
        seq_x = self.x[x_begin:x_end]
        seq_y = self.y[y_begin:y_end]
        return seq_x, seq_y

    def inverse_transform(self, data):
        return self.scaler.inverse_transform(data)

# %% [markdown]
# ## <a id='toc1_2_'></a>[LSTM model class](#toc0_)

# %%
import torch
from torch import nn


class LSTM(nn.Module):

    def __init__(self, input_size: int, hidden_size: int, num_layers: int,
                 batch_size: int, output_size: int, **kwargs):
        super(LSTM, self).__init__()
        # rnn = nn.LSTM(input_size=10, hidden_size=20, num_layers=2) # input_size - number of expected features in the input x, hidden_size -  number of features in the hidden state h

        # Inputs:
        # input = torch.randn(5, 3, 10) # [batch_size, input_size] for unbatched input, [seq_len, batch_size, input_size] when batch_first=False, [batch_size, seq_len, input_size] when batch_first=True

        # h0 = torch.randn(2, 3, 20) # [D * num_layers, hidden_size] for unbatched input, [D * num_layers, barch_size, hidden_size] , D = 2 if birectional=True, otherwise 1
        # c0 = torch.randn(2, 3, 20)
        # output, (hn, cn) = rnn(input, (h0, c0))
        self.input_size = input_size  # number of expected features in the input
        self.hidden_size = hidden_size  # number of features in the hidden state
        self.output_size = output_size
        self.num_layers = num_layers
        self.batch_size = batch_size
        self.lstm = nn.LSTM(input_size=self.input_size,
                            hidden_size=self.hidden_size,
                            num_layers=self.num_layers,
                            batch_first=True,
                            dtype=torch.float)
        self.linear = nn.Linear(self.hidden_size,
                                self.output_size,
                                dtype=torch.float)
        self.h0 = torch.randn(self.num_layers,
                              self.batch_size,
                              self.hidden_size,
                              dtype=torch.float)
        self.c0 = torch.randn(self.num_layers,
                              self.batch_size,
                              self.hidden_size,
                              dtype=torch.float)

    def forward(self, input):
        # input [self.batch_size, self.seq_len, self.input_size]
        output, (hn, cn) = self.lstm(input, (self.h0, self.c0))
        output = self.linear(output)
        return output

# %% [markdown]
# ## <a id='toc1_3_'></a>[Early stopping class](#toc0_)

# %%
import torch
from torch import optim
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime


class EarlyStopping:

    def __init__(self, patience: int, verbose: bool = True, delta: int = 0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = float('inf')
        self.delta = delta

    def __call__(self, val_loss, model, path='./runs'):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.path = os.path.join(path)
            self.save_checkpoint(val_loss, model, self.path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(
                f'EarlyStopping counter: {self.counter} out of {self.patience}'
            )
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, self.path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(
                f'validation loss decreased ({self.val_loss_min:.3f} --> {val_loss:.3f})',
                'saving model',
                sep='\n')
        os.makedirs(path, exist_ok=True)
        torch.save(model, os.path.join(path, 'checkpoint.pth'))
        self.val_loss_min = val_loss

# %% [markdown]
# ## <a id='toc1_4_'></a>[Experiment class](#toc0_)

# %%
import matplotlib.pyplot as plt

class Experiment:

    def __init__(self, args):
        self.args = args
        torch.manual_seed(self.args['seed'])

    def _select_criterion(self):
        return nn.MSELoss()

    def _select_optimizer(self):
        return optim.Adam(self.model.parameters(),
                          lr=self.args['learning_rate'])

    def _get_data(self, flag):
        if flag in ['test', 'pred']:
            shuffle_flag = False
        else:
            shuffle_flag = True
        data = BiddingData(seq_len=self.args['seq_len'],
                           pred_len=self.args['pred_len'],
                           features=self.args['features'],
                           val_split=self.args['val_split'],
                           test_split=self.args['test_split'],
                           target=self.args['target'],
                           cluster=self.args['cluster'],
                           scale=True,
                           flag=flag)
        loader = DataLoader(dataset=data,
                            batch_size=self.args['batch_size'],
                            shuffle=shuffle_flag,
                            drop_last=True)
        return data, loader

    def _build_model(self):
        model = LSTM
        return model(input_size=self.train_data.x.shape[-1],
                     output_size=self.train_data.y.shape[-1],
                     hidden_size=self.args['hidden_size'],
                     num_layers=self.args['num_layers'],
                     batch_size=self.args['batch_size'])

    def train(self):
        self.train_data, self.train_loader = self._get_data(flag='train')
        self.val_data, self.val_loader = self._get_data(flag='val')
        self.test_data, self.test_loader = self._get_data(flag='test')
        self.model = self._build_model()
        model_optim = self._select_optimizer()
        criterion = self._select_criterion()
        train_steps = len(self.train_loader)
        early_stopping = EarlyStopping(patience=self.args['patience'],
                                       verbose=True)
        self.path = os.path.join(os.environ['RUNS_PATH'],
                                 self.args['timestamp'],
                                 f'cluster_{self.args["cluster"]}')
        os.makedirs(self.path, exist_ok=True)
        for epoch in range(self.args['epochs']):
            print('epoch: {}'.format(epoch + 1))
            train_losses = []
            self.model.train()
            epoch_time = datetime.now()
            self.writer = SummaryWriter(log_dir=os.path.join(
                self.path, 'tensorboards', f'epoc_{epoch+1}'))
            for i, (batch_x, batch_y) in enumerate(self.train_loader):
                batch_x = batch_x.float()
                batch_y = batch_y.float()
                model_optim.zero_grad()
                pred = self.model(batch_x)
                pred = pred[:, -self.args['pred_len']:, :]
                loss = torch.sqrt(criterion(pred, batch_y))
                self.writer.add_scalar('loss train/iter', loss, i)
                train_losses.append(loss.item())
                if i % self.args['log_interval'] == 0:
                    print('\titer: {0:>5d}/{1:>5d} | loss: {2:.3f}'.format(
                        i, train_steps, loss.item()))
                loss.backward()
                model_optim.step()
            train_loss = np.mean(train_losses)
            val_loss = self.evaluate(self.val_loader, criterion)
            test_loss = self.evaluate(self.test_loader, criterion)
            print('epoch {0} time: {1} s'.format(epoch + 1,
                                                 datetime.now() - epoch_time))
            print(
                'train loss: {0:.3f} | val loss: {1:.3f} | test loss: {2:.3f}'.
                format(train_loss, val_loss, test_loss))
            early_stopping(val_loss, self.model, self.path)
            self.writer.flush()
            if early_stopping.early_stop:
                print('early stopping!')
                break
            self.writer.close()
        best_model_path = os.path.join(self.path, 'checkpoint.pth')
        self.model = torch.load(best_model_path)
        return self.model

    def evaluate(self, loader, criterion):
        losses = []
        self.model.eval()
        with torch.no_grad():
            for i, (batch_x, batch_y) in enumerate(loader):
                batch_x = batch_x.float()
                batch_y = batch_y.float()
                pred = self.model(batch_x)
                pred = pred[:, -self.args['pred_len']:, :]
                loss = torch.sqrt(criterion(pred, batch_y))
                self.writer.add_scalar(f'loss {loader.dataset.flag}/iter',
                                       loss, i)
                losses.append(loss.item())
        loss = np.mean(losses)
        self.model.train()
        return loss

    def test(self):
        self.test_data, self.test_loader = self._get_data(flag='test')
        preds = []
        trues = []
        test_folder = os.path.join(self.path, 'test_results')
        os.makedirs(test_folder, exist_ok=True)
        self.model.eval()
        with torch.no_grad():
            for i, (batch_x, batch_y) in enumerate(self.test_loader):
                batch_x = batch_x.float()
                batch_y = batch_y.float()
                pred = self.model(batch_x)
                pred = torch.flatten(pred[:, -self.args['pred_len']:, -1])
                true = torch.flatten(batch_y.float())
                preds.append(pred.detach().cpu().numpy())
                trues.append(true.detach().cpu().numpy())
        preds = np.array(preds).flatten()
        trues = np.array(trues).flatten()
        visual(
            preds, trues,
            os.path.join(self.path,
                         f'test_cluster_{self.args["cluster"]}.pdf'))

    def predict(self):
        pred_data, pred_loader = self._get_data(flag='train')
        self.model.load_state_dict(torch.load(self.best_model_path))
        preds = []
        self.model.eval()
        with torch.no_grad():
            for i, (batch_x, batch_y) in enumerate(pred_loader):
                batch_x = batch_x.float().to(self.device)
                batch_y = batch_y.float()
                pred = self.model(batch_x)
                preds.append(pred)
        preds = np.array(preds)
        preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1])
        if (pred_data.scale):
            preds = pred_data.inverse_transform(preds)


def visual(true, preds, name):
    plt.figure()
    plt.plot(true, label='test ground truth', linewidth=2)
    if preds is not None:
        plt.plot(preds, label='test prediction', linewidth=2)
    plt.legend()
    plt.savefig(name, bbox_inches='tight')
    plt.close()

# %% [markdown]
# ## Features

# %%
features = [
    'Impressions',
    'AbsoluteTopImpressionPercentage',
    'TopImpressionPercentage',
    'SearchImpressionShare',
    'SearchTopImpressionShare',
    'SearchRankLostTopImpressionShare',
    'Clicks',
    'Cost_gbp',
    'CpcBid_gbp',
]
features_date = features + ['Date']
target = 'CpcBid_gbp'
features.remove(target)
with open(
        os.path.join(os.environ['MODELS_PATH'], 'kmeans_clustered_dict.json'),
        'r') as f:
    clustered = json.load(f)

# %% [markdown]
# ## <a id='toc1_5_'></a>[Parameters](#toc0_)

# %%
SEED = 10
task_params = dict(seq_len=14, pred_len=1, features=features, target=target)
training_params = dict(val_split=0.2,
                       test_split=0.2,
                       batch_size=4,
                       patience=20,
                       epochs=500,
                       learning_rate=0.01,
                       log_interval=10,
                       seed=SEED)
model_params = dict(hidden_size=10, num_layers=2)

# %% [markdown]
# ## <a id='toc1_6_'></a>[Model](#toc0_)

# %%
exp = Experiment(
    {
        **task_params,
        **training_params,
        **model_params,
        'cluster': 0,
        'timestamp': '',
    }, )
exp.train_data, exp.train_loader = exp._get_data(flag='train')
exp._build_model()
# Out:
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# LSTM(
#   (lstm): LSTM(8, 10, num_layers=2, batch_first=True)
#   (linear): Linear(in_features=10, out_features=1, bias=True)
# )

# %% [markdown]
# ## <a id='toc1_7_'></a>[Training](#toc0_)

# %%
timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
for f in os.listdir(os.environ['PROCESSED_DATA_PATH']):
    if f.endswith('.csv'):
        exp = Experiment({
            **task_params,
            **training_params,
            **model_params, 'cluster':
            f.rstrip('.csv').lstrip('processed_'),
            'timestamp':
            timestamp
        })
        exp.train()
        exp.test()
# Out:
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# epoch: 1
# 	iter:     0/   17 | loss: 0.781
# 	iter:    10/   17 | loss: 0.899
# epoch 1 time: 0:00:03.941642 s
# train loss: 0.899 | val loss: 0.672 | test loss: 0.401
# validation loss decreased (inf --> 0.672)
# saving model
# epoch: 2
# 	iter:     0/   17 | loss: 0.793
# 	iter:    10/   17 | loss: 0.253
# epoch 2 time: 0:00:00.170021 s
# train loss: 0.342 | val loss: 0.319 | test loss: 1.121
# validation loss decreased (0.672 --> 0.319)
# saving model
# epoch: 3
# 	iter:     0/   17 | loss: 0.247
# 	iter:    10/   17 | loss: 0.108
# epoch 3 time: 0:00:00.162647 s
# train loss: 0.258 | val loss: 0.415 | test loss: 1.304
# EarlyStopping counter: 1 out of 20
# epoch: 4
# 	iter:     0/   17 | loss: 0.119
# 	iter:    10/   17 | loss: 0.083
# epoch 4 time: 0:00:00.134539 s
# train loss: 0.253 | val loss: 0.350 | test loss: 1.015
# EarlyStopping counter: 2 out of 20
# epoch: 5
# 	iter:     0/   17 | loss: 0.106
# 	iter:    10/   17 | loss: 0.470
# epoch 5 time: 0:00:00.134685 s
# train loss: 0.200 | val loss: 0.290 | test loss: 0.796
# validation loss decreased (0.319 --> 0.290)
# saving model
# epoch: 6
# 	iter:     0/   17 | loss: 0.102
# 	iter:    10/   17 | loss: 0.300
# epoch 6 time: 0:00:00.134595 s
# train loss: 0.207 | val loss: 0.524 | test loss: 1.166
# EarlyStopping counter: 1 out of 20
# epoch: 7
# 	iter:     0/   17 | loss: 0.417
# 	iter:    10/   17 | loss: 0.069
# epoch 7 time: 0:00:00.124025 s
# train loss: 0.203 | val loss: 0.367 | test loss: 1.021
# EarlyStopping counter: 2 out of 20
# epoch: 8
# 	iter:     0/   17 | loss: 0.318
# 	iter:    10/   17 | loss: 0.157
# epoch 8 time: 0:00:00.125254 s
# train loss: 0.204 | val loss: 0.432 | test loss: 1.089
# EarlyStopping counter: 3 out of 20
# epoch: 9
# 	iter:     0/   17 | loss: 0.138
# 	iter:    10/   17 | loss: 0.088
# epoch 9 time: 0:00:00.115922 s
# train loss: 0.175 | val loss: 0.452 | test loss: 1.312
# EarlyStopping counter: 4 out of 20
# epoch: 10
# 	iter:     0/   17 | loss: 0.349
# 	iter:    10/   17 | loss: 0.374
# epoch 10 time: 0:00:00.117086 s
# train loss: 0.197 | val loss: 0.369 | test loss: 1.171
# EarlyStopping counter: 5 out of 20
# epoch: 11
# 	iter:     0/   17 | loss: 0.382
# 	iter:    10/   17 | loss: 0.045
# epoch 11 time: 0:00:00.116667 s
# train loss: 0.192 | val loss: 0.347 | test loss: 1.031
# EarlyStopping counter: 6 out of 20
# epoch: 12
# 	iter:     0/   17 | loss: 0.097
# 	iter:    10/   17 | loss: 0.064
# epoch 12 time: 0:00:00.132675 s
# train loss: 0.167 | val loss: 0.499 | test loss: 1.161
# EarlyStopping counter: 7 out of 20
# epoch: 13
# 	iter:     0/   17 | loss: 0.310
# 	iter:    10/   17 | loss: 0.059
# epoch 13 time: 0:00:00.124277 s
# train loss: 0.169 | val loss: 0.527 | test loss: 1.032
# EarlyStopping counter: 8 out of 20
# epoch: 14
# 	iter:     0/   17 | loss: 0.341
# 	iter:    10/   17 | loss: 0.131
# epoch 14 time: 0:00:00.124579 s
# train loss: 0.172 | val loss: 0.413 | test loss: 1.230
# EarlyStopping counter: 9 out of 20
# epoch: 15
# 	iter:     0/   17 | loss: 0.053
# 	iter:    10/   17 | loss: 0.073
# epoch 15 time: 0:00:00.125934 s
# train loss: 0.188 | val loss: 0.707 | test loss: 1.298
# EarlyStopping counter: 10 out of 20
# epoch: 16
# 	iter:     0/   17 | loss: 0.366
# 	iter:    10/   17 | loss: 0.198
# epoch 16 time: 0:00:00.129715 s
# train loss: 0.155 | val loss: 0.550 | test loss: 1.062
# EarlyStopping counter: 11 out of 20
# epoch: 17
# 	iter:     0/   17 | loss: 0.158
# 	iter:    10/   17 | loss: 0.067
# epoch 17 time: 0:00:00.122904 s
# train loss: 0.125 | val loss: 0.645 | test loss: 1.208
# EarlyStopping counter: 12 out of 20
# epoch: 18
# 	iter:     0/   17 | loss: 0.224
# 	iter:    10/   17 | loss: 0.198
# epoch 18 time: 0:00:00.119499 s
# train loss: 0.135 | val loss: 0.742 | test loss: 1.262
# EarlyStopping counter: 13 out of 20
# epoch: 19
# 	iter:     0/   17 | loss: 0.501
# 	iter:    10/   17 | loss: 0.124
# epoch 19 time: 0:00:00.115549 s
# train loss: 0.139 | val loss: 0.428 | test loss: 1.190
# EarlyStopping counter: 14 out of 20
# epoch: 20
# 	iter:     0/   17 | loss: 0.064
# 	iter:    10/   17 | loss: 0.065
# epoch 20 time: 0:00:00.115199 s
# train loss: 0.109 | val loss: 0.729 | test loss: 1.149
# EarlyStopping counter: 15 out of 20
# epoch: 21
# 	iter:     0/   17 | loss: 0.069
# 	iter:    10/   17 | loss: 0.107
# epoch 21 time: 0:00:00.115575 s
# train loss: 0.116 | val loss: 1.030 | test loss: 0.997
# EarlyStopping counter: 16 out of 20
# epoch: 22
# 	iter:     0/   17 | loss: 0.086
# 	iter:    10/   17 | loss: 0.091
# epoch 22 time: 0:00:00.116769 s
# train loss: 0.110 | val loss: 1.023 | test loss: 1.055
# EarlyStopping counter: 17 out of 20
# epoch: 23
# 	iter:     0/   17 | loss: 0.091
# 	iter:    10/   17 | loss: 0.105
# epoch 23 time: 0:00:00.116667 s
# train loss: 0.100 | val loss: 0.760 | test loss: 1.158
# EarlyStopping counter: 18 out of 20
# epoch: 24
# 	iter:     0/   17 | loss: 0.043
# 	iter:    10/   17 | loss: 0.150
# epoch 24 time: 0:00:00.117193 s
# train loss: 0.099 | val loss: 0.749 | test loss: 1.100
# EarlyStopping counter: 19 out of 20
# epoch: 25
# 	iter:     0/   17 | loss: 0.072
# 	iter:    10/   17 | loss: 0.109
# epoch 25 time: 0:00:00.115225 s
# train loss: 0.077 | val loss: 0.664 | test loss: 1.151
# EarlyStopping counter: 20 out of 20
# early stopping!
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# epoch: 1
# 	iter:     0/   17 | loss: 0.780
# 	iter:    10/   17 | loss: 0.891
# epoch 1 time: 0:00:00.133593 s
# train loss: 0.854 | val loss: 0.723 | test loss: 0.296
# validation loss decreased (inf --> 0.723)
# saving model
# epoch: 2
# 	iter:     0/   17 | loss: 0.668
# 	iter:    10/   17 | loss: 0.265
# epoch 2 time: 0:00:00.136969 s
# train loss: 0.310 | val loss: 1.064 | test loss: 0.723
# EarlyStopping counter: 1 out of 20
# epoch: 3
# 	iter:     0/   17 | loss: 0.276
# 	iter:    10/   17 | loss: 0.320
# epoch 3 time: 0:00:00.137604 s
# train loss: 0.230 | val loss: 0.878 | test loss: 0.764
# EarlyStopping counter: 2 out of 20
# epoch: 4
# 	iter:     0/   17 | loss: 0.157
# 	iter:    10/   17 | loss: 0.048
# epoch 4 time: 0:00:00.133216 s
# train loss: 0.223 | val loss: 0.882 | test loss: 0.559
# EarlyStopping counter: 3 out of 20
# epoch: 5
# 	iter:     0/   17 | loss: 0.191
# 	iter:    10/   17 | loss: 0.548
# epoch 5 time: 0:00:00.131222 s
# train loss: 0.214 | val loss: 0.933 | test loss: 0.616
# EarlyStopping counter: 4 out of 20
# epoch: 6
# 	iter:     0/   17 | loss: 0.116
# 	iter:    10/   17 | loss: 0.356
# epoch 6 time: 0:00:00.139519 s
# train loss: 0.217 | val loss: 1.115 | test loss: 0.744
# EarlyStopping counter: 5 out of 20
# epoch: 7
# 	iter:     0/   17 | loss: 0.353
# 	iter:    10/   17 | loss: 0.106
# epoch 7 time: 0:00:00.129700 s
# train loss: 0.223 | val loss: 0.947 | test loss: 0.691
# EarlyStopping counter: 6 out of 20
# epoch: 8
# 	iter:     0/   17 | loss: 0.277
# 	iter:    10/   17 | loss: 0.098
# epoch 8 time: 0:00:00.111591 s
# train loss: 0.213 | val loss: 1.146 | test loss: 0.688
# EarlyStopping counter: 7 out of 20
# epoch: 9
# 	iter:     0/   17 | loss: 0.147
# 	iter:    10/   17 | loss: 0.135
# epoch 9 time: 0:00:00.114570 s
# train loss: 0.196 | val loss: 0.501 | test loss: 0.881
# validation loss decreased (0.723 --> 0.501)
# saving model
# epoch: 10
# 	iter:     0/   17 | loss: 0.369
# 	iter:    10/   17 | loss: 0.419
# epoch 10 time: 0:00:00.116598 s
# train loss: 0.224 | val loss: 0.787 | test loss: 0.607
# EarlyStopping counter: 1 out of 20
# epoch: 11
# 	iter:     0/   17 | loss: 0.400
# 	iter:    10/   17 | loss: 0.056
# epoch 11 time: 0:00:00.117350 s
# train loss: 0.206 | val loss: 0.799 | test loss: 0.609
# EarlyStopping counter: 2 out of 20
# epoch: 12
# 	iter:     0/   17 | loss: 0.124
# 	iter:    10/   17 | loss: 0.063
# epoch 12 time: 0:00:00.128863 s
# train loss: 0.179 | val loss: 0.707 | test loss: 0.629
# EarlyStopping counter: 3 out of 20
# epoch: 13
# 	iter:     0/   17 | loss: 0.326
# 	iter:    10/   17 | loss: 0.123
# epoch 13 time: 0:00:00.140572 s
# train loss: 0.188 | val loss: 1.038 | test loss: 0.533
# EarlyStopping counter: 4 out of 20
# epoch: 14
# 	iter:     0/   17 | loss: 0.301
# 	iter:    10/   17 | loss: 0.165
# epoch 14 time: 0:00:00.122116 s
# train loss: 0.206 | val loss: 0.647 | test loss: 0.605
# EarlyStopping counter: 5 out of 20
# epoch: 15
# 	iter:     0/   17 | loss: 0.061
# 	iter:    10/   17 | loss: 0.096
# epoch 15 time: 0:00:00.117494 s
# train loss: 0.173 | val loss: 0.559 | test loss: 0.713
# EarlyStopping counter: 6 out of 20
# epoch: 16
# 	iter:     0/   17 | loss: 0.327
# 	iter:    10/   17 | loss: 0.178
# epoch 16 time: 0:00:00.113003 s
# train loss: 0.167 | val loss: 0.332 | test loss: 0.502
# validation loss decreased (0.501 --> 0.332)
# saving model
# epoch: 17
# 	iter:     0/   17 | loss: 0.124
# 	iter:    10/   17 | loss: 0.062
# epoch 17 time: 0:00:00.115641 s
# train loss: 0.189 | val loss: 1.039 | test loss: 0.520
# EarlyStopping counter: 1 out of 20
# epoch: 18
# 	iter:     0/   17 | loss: 0.221
# 	iter:    10/   17 | loss: 0.267
# epoch 18 time: 0:00:00.117149 s
# train loss: 0.182 | val loss: 0.755 | test loss: 0.644
# EarlyStopping counter: 2 out of 20
# epoch: 19
# 	iter:     0/   17 | loss: 0.372
# 	iter:    10/   17 | loss: 0.093
# epoch 19 time: 0:00:00.128585 s
# train loss: 0.132 | val loss: 0.697 | test loss: 0.541
# EarlyStopping counter: 3 out of 20
# epoch: 20
# 	iter:     0/   17 | loss: 0.054
# 	iter:    10/   17 | loss: 0.180
# epoch 20 time: 0:00:00.117933 s
# train loss: 0.143 | val loss: 0.771 | test loss: 0.461
# EarlyStopping counter: 4 out of 20
# epoch: 21
# 	iter:     0/   17 | loss: 0.130
# 	iter:    10/   17 | loss: 0.142
# epoch 21 time: 0:00:00.121885 s
# train loss: 0.166 | val loss: 0.917 | test loss: 0.538
# EarlyStopping counter: 5 out of 20
# epoch: 22
# 	iter:     0/   17 | loss: 0.136
# 	iter:    10/   17 | loss: 0.157
# epoch 22 time: 0:00:00.113681 s
# train loss: 0.162 | val loss: 0.851 | test loss: 0.451
# EarlyStopping counter: 6 out of 20
# epoch: 23
# 	iter:     0/   17 | loss: 0.145
# 	iter:    10/   17 | loss: 0.141
# epoch 23 time: 0:00:00.125338 s
# train loss: 0.148 | val loss: 0.631 | test loss: 0.560
# EarlyStopping counter: 7 out of 20
# epoch: 24
# 	iter:     0/   17 | loss: 0.145
# 	iter:    10/   17 | loss: 0.076
# epoch 24 time: 0:00:00.123081 s
# train loss: 0.113 | val loss: 0.638 | test loss: 0.470
# EarlyStopping counter: 8 out of 20
# epoch: 25
# 	iter:     0/   17 | loss: 0.063
# 	iter:    10/   17 | loss: 0.100
# epoch 25 time: 0:00:00.115429 s
# train loss: 0.098 | val loss: 0.862 | test loss: 0.553
# EarlyStopping counter: 9 out of 20
# epoch: 26
# 	iter:     0/   17 | loss: 0.109
# 	iter:    10/   17 | loss: 0.118
# epoch 26 time: 0:00:00.110867 s
# train loss: 0.112 | val loss: 0.863 | test loss: 0.571
# EarlyStopping counter: 10 out of 20
# epoch: 27
# 	iter:     0/   17 | loss: 0.060
# 	iter:    10/   17 | loss: 0.067
# epoch 27 time: 0:00:00.140213 s
# train loss: 0.120 | val loss: 0.824 | test loss: 0.540
# EarlyStopping counter: 11 out of 20
# epoch: 28
# 	iter:     0/   17 | loss: 0.087
# 	iter:    10/   17 | loss: 0.022
# epoch 28 time: 0:00:00.194916 s
# train loss: 0.102 | val loss: 0.722 | test loss: 0.547
# EarlyStopping counter: 12 out of 20
# epoch: 29
# 	iter:     0/   17 | loss: 0.073
# 	iter:    10/   17 | loss: 0.332
# epoch 29 time: 0:00:00.162114 s
# train loss: 0.118 | val loss: 0.881 | test loss: 0.513
# EarlyStopping counter: 13 out of 20
# epoch: 30
# 	iter:     0/   17 | loss: 0.038
# 	iter:    10/   17 | loss: 0.081
# epoch 30 time: 0:00:00.162134 s
# train loss: 0.093 | val loss: 0.971 | test loss: 0.494
# EarlyStopping counter: 14 out of 20
# epoch: 31
# 	iter:     0/   17 | loss: 0.051
# 	iter:    10/   17 | loss: 0.167
# epoch 31 time: 0:00:00.174574 s
# train loss: 0.091 | val loss: 1.086 | test loss: 0.539
# EarlyStopping counter: 15 out of 20
# epoch: 32
# 	iter:     0/   17 | loss: 0.115
# 	iter:    10/   17 | loss: 0.200
# epoch 32 time: 0:00:00.172076 s
# train loss: 0.131 | val loss: 0.934 | test loss: 0.567
# EarlyStopping counter: 16 out of 20
# epoch: 33
# 	iter:     0/   17 | loss: 0.118
# 	iter:    10/   17 | loss: 0.147
# epoch 33 time: 0:00:00.141096 s
# train loss: 0.098 | val loss: 0.947 | test loss: 0.572
# EarlyStopping counter: 17 out of 20
# epoch: 34
# 	iter:     0/   17 | loss: 0.020
# 	iter:    10/   17 | loss: 0.115
# epoch 34 time: 0:00:00.123517 s
# train loss: 0.089 | val loss: 1.037 | test loss: 0.554
# EarlyStopping counter: 18 out of 20
# epoch: 35
# 	iter:     0/   17 | loss: 0.041
# 	iter:    10/   17 | loss: 0.033
# epoch 35 time: 0:00:00.121512 s
# train loss: 0.093 | val loss: 0.880 | test loss: 0.578
# EarlyStopping counter: 19 out of 20
# epoch: 36
# 	iter:     0/   17 | loss: 0.082
# 	iter:    10/   17 | loss: 0.024
# epoch 36 time: 0:00:00.172165 s
# train loss: 0.075 | val loss: 1.035 | test loss: 0.575
# EarlyStopping counter: 20 out of 20
# early stopping!
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# epoch: 1
# 	iter:     0/   17 | loss: 0.781
# 	iter:    10/   17 | loss: 0.845
# epoch 1 time: 0:00:00.136263 s
# train loss: 0.859 | val loss: 0.732 | test loss: 0.219
# validation loss decreased (inf --> 0.732)
# saving model
# epoch: 2
# 	iter:     0/   17 | loss: 0.670
# 	iter:    10/   17 | loss: 0.301
# epoch 2 time: 0:00:00.144048 s
# train loss: 0.293 | val loss: 0.281 | test loss: 0.572
# validation loss decreased (0.732 --> 0.281)
# saving model
# epoch: 3
# 	iter:     0/   17 | loss: 0.151
# 	iter:    10/   17 | loss: 0.267
# epoch 3 time: 0:00:00.128566 s
# train loss: 0.279 | val loss: 0.441 | test loss: 0.766
# EarlyStopping counter: 1 out of 20
# epoch: 4
# 	iter:     0/   17 | loss: 0.099
# 	iter:    10/   17 | loss: 0.131
# epoch 4 time: 0:00:00.138934 s
# train loss: 0.260 | val loss: 0.601 | test loss: 0.580
# EarlyStopping counter: 2 out of 20
# epoch: 5
# 	iter:     0/   17 | loss: 0.072
# 	iter:    10/   17 | loss: 0.493
# epoch 5 time: 0:00:00.129834 s
# train loss: 0.220 | val loss: 0.658 | test loss: 0.650
# EarlyStopping counter: 3 out of 20
# epoch: 6
# 	iter:     0/   17 | loss: 0.038
# 	iter:    10/   17 | loss: 0.289
# epoch 6 time: 0:00:00.144775 s
# train loss: 0.219 | val loss: 0.629 | test loss: 0.778
# EarlyStopping counter: 4 out of 20
# epoch: 7
# 	iter:     0/   17 | loss: 0.468
# 	iter:    10/   17 | loss: 0.048
# epoch 7 time: 0:00:00.120214 s
# train loss: 0.225 | val loss: 1.005 | test loss: 0.755
# EarlyStopping counter: 5 out of 20
# epoch: 8
# 	iter:     0/   17 | loss: 0.098
# 	iter:    10/   17 | loss: 0.094
# epoch 8 time: 0:00:00.117998 s
# train loss: 0.188 | val loss: 0.366 | test loss: 0.682
# EarlyStopping counter: 6 out of 20
# epoch: 9
# 	iter:     0/   17 | loss: 0.065
# 	iter:    10/   17 | loss: 0.116
# epoch 9 time: 0:00:00.115680 s
# train loss: 0.187 | val loss: 0.483 | test loss: 0.769
# EarlyStopping counter: 7 out of 20
# epoch: 10
# 	iter:     0/   17 | loss: 0.344
# 	iter:    10/   17 | loss: 0.412
# epoch 10 time: 0:00:00.115798 s
# train loss: 0.213 | val loss: 0.755 | test loss: 0.793
# EarlyStopping counter: 8 out of 20
# epoch: 11
# 	iter:     0/   17 | loss: 0.375
# 	iter:    10/   17 | loss: 0.119
# epoch 11 time: 0:00:00.113085 s
# train loss: 0.205 | val loss: 0.829 | test loss: 0.732
# EarlyStopping counter: 9 out of 20
# epoch: 12
# 	iter:     0/   17 | loss: 0.074
# 	iter:    10/   17 | loss: 0.067
# epoch 12 time: 0:00:00.115294 s
# train loss: 0.167 | val loss: 0.840 | test loss: 0.702
# EarlyStopping counter: 10 out of 20
# epoch: 13
# 	iter:     0/   17 | loss: 0.327
# 	iter:    10/   17 | loss: 0.082
# epoch 13 time: 0:00:00.114614 s
# train loss: 0.178 | val loss: 0.987 | test loss: 0.646
# EarlyStopping counter: 11 out of 20
# epoch: 14
# 	iter:     0/   17 | loss: 0.326
# 	iter:    10/   17 | loss: 0.128
# epoch 14 time: 0:00:00.115462 s
# train loss: 0.181 | val loss: 0.683 | test loss: 0.725
# EarlyStopping counter: 12 out of 20
# epoch: 15
# 	iter:     0/   17 | loss: 0.072
# 	iter:    10/   17 | loss: 0.074
# epoch 15 time: 0:00:00.134525 s
# train loss: 0.186 | val loss: 1.005 | test loss: 0.891
# EarlyStopping counter: 13 out of 20
# epoch: 16
# 	iter:     0/   17 | loss: 0.362
# 	iter:    10/   17 | loss: 0.191
# epoch 16 time: 0:00:00.119747 s
# train loss: 0.175 | val loss: 0.725 | test loss: 0.719
# EarlyStopping counter: 14 out of 20
# epoch: 17
# 	iter:     0/   17 | loss: 0.131
# 	iter:    10/   17 | loss: 0.085
# epoch 17 time: 0:00:00.112697 s
# train loss: 0.151 | val loss: 1.005 | test loss: 0.774
# EarlyStopping counter: 15 out of 20
# epoch: 18
# 	iter:     0/   17 | loss: 0.192
# 	iter:    10/   17 | loss: 0.330
# epoch 18 time: 0:00:00.115753 s
# train loss: 0.143 | val loss: 0.864 | test loss: 0.797
# EarlyStopping counter: 16 out of 20
# epoch: 19
# 	iter:     0/   17 | loss: 0.391
# 	iter:    10/   17 | loss: 0.053
# epoch 19 time: 0:00:00.114721 s
# train loss: 0.121 | val loss: 1.192 | test loss: 0.758
# EarlyStopping counter: 17 out of 20
# epoch: 20
# 	iter:     0/   17 | loss: 0.047
# 	iter:    10/   17 | loss: 0.223
# epoch 20 time: 0:00:00.116738 s
# train loss: 0.125 | val loss: 0.830 | test loss: 0.731
# EarlyStopping counter: 18 out of 20
# epoch: 21
# 	iter:     0/   17 | loss: 0.048
# 	iter:    10/   17 | loss: 0.091
# epoch 21 time: 0:00:00.112626 s
# train loss: 0.125 | val loss: 1.014 | test loss: 0.721
# EarlyStopping counter: 19 out of 20
# epoch: 22
# 	iter:     0/   17 | loss: 0.085
# 	iter:    10/   17 | loss: 0.066
# epoch 22 time: 0:00:00.119537 s
# train loss: 0.111 | val loss: 0.974 | test loss: 0.716
# EarlyStopping counter: 20 out of 20
# early stopping!
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# epoch: 1
# 	iter:     0/   17 | loss: 0.824
# 	iter:    10/   17 | loss: 0.852
# epoch 1 time: 0:00:00.117621 s
# train loss: 0.875 | val loss: 0.530 | test loss: 0.764
# validation loss decreased (inf --> 0.530)
# saving model
# epoch: 2
# 	iter:     0/   17 | loss: 0.737
# 	iter:    10/   17 | loss: 0.294
# epoch 2 time: 0:00:00.116181 s
# train loss: 0.346 | val loss: 0.710 | test loss: 1.534
# EarlyStopping counter: 1 out of 20
# epoch: 3
# 	iter:     0/   17 | loss: 0.488
# 	iter:    10/   17 | loss: 0.423
# epoch 3 time: 0:00:00.114700 s
# train loss: 0.288 | val loss: 0.794 | test loss: 1.655
# EarlyStopping counter: 2 out of 20
# epoch: 4
# 	iter:     0/   17 | loss: 0.254
# 	iter:    10/   17 | loss: 0.103
# epoch 4 time: 0:00:00.116991 s
# train loss: 0.239 | val loss: 0.620 | test loss: 0.738
# EarlyStopping counter: 3 out of 20
# epoch: 5
# 	iter:     0/   17 | loss: 0.301
# 	iter:    10/   17 | loss: 0.486
# epoch 5 time: 0:00:00.132633 s
# train loss: 0.295 | val loss: 0.718 | test loss: 1.570
# EarlyStopping counter: 4 out of 20
# epoch: 6
# 	iter:     0/   17 | loss: 0.102
# 	iter:    10/   17 | loss: 0.271
# epoch 6 time: 0:00:00.199754 s
# train loss: 0.218 | val loss: 0.795 | test loss: 1.616
# EarlyStopping counter: 5 out of 20
# epoch: 7
# 	iter:     0/   17 | loss: 0.398
# 	iter:    10/   17 | loss: 0.087
# epoch 7 time: 0:00:00.183076 s
# train loss: 0.198 | val loss: 0.754 | test loss: 1.361
# EarlyStopping counter: 6 out of 20
# epoch: 8
# 	iter:     0/   17 | loss: 0.259
# 	iter:    10/   17 | loss: 0.154
# epoch 8 time: 0:00:00.158126 s
# train loss: 0.179 | val loss: 0.734 | test loss: 1.476
# EarlyStopping counter: 7 out of 20
# epoch: 9
# 	iter:     0/   17 | loss: 0.090
# 	iter:    10/   17 | loss: 0.174
# epoch 9 time: 0:00:00.158634 s
# train loss: 0.166 | val loss: 0.895 | test loss: 1.620
# EarlyStopping counter: 8 out of 20
# epoch: 10
# 	iter:     0/   17 | loss: 0.212
# 	iter:    10/   17 | loss: 0.272
# epoch 10 time: 0:00:00.144175 s
# train loss: 0.172 | val loss: 0.873 | test loss: 1.512
# EarlyStopping counter: 9 out of 20
# epoch: 11
# 	iter:     0/   17 | loss: 0.205
# 	iter:    10/   17 | loss: 0.236
# epoch 11 time: 0:00:00.141674 s
# train loss: 0.164 | val loss: 0.838 | test loss: 1.401
# EarlyStopping counter: 10 out of 20
# epoch: 12
# 	iter:     0/   17 | loss: 0.088
# 	iter:    10/   17 | loss: 0.050
# epoch 12 time: 0:00:00.154280 s
# train loss: 0.140 | val loss: 0.748 | test loss: 1.424
# EarlyStopping counter: 11 out of 20
# epoch: 13
# 	iter:     0/   17 | loss: 0.069
# 	iter:    10/   17 | loss: 0.061
# epoch 13 time: 0:00:00.139597 s
# train loss: 0.125 | val loss: 0.734 | test loss: 1.390
# EarlyStopping counter: 12 out of 20
# epoch: 14
# 	iter:     0/   17 | loss: 0.133
# 	iter:    10/   17 | loss: 0.165
# epoch 14 time: 0:00:00.149167 s
# train loss: 0.121 | val loss: 0.783 | test loss: 1.451
# EarlyStopping counter: 13 out of 20
# epoch: 15
# 	iter:     0/   17 | loss: 0.052
# 	iter:    10/   17 | loss: 0.025
# epoch 15 time: 0:00:00.137557 s
# train loss: 0.115 | val loss: 0.620 | test loss: 1.525
# EarlyStopping counter: 14 out of 20
# epoch: 16
# 	iter:     0/   17 | loss: 0.109
# 	iter:    10/   17 | loss: 0.213
# epoch 16 time: 0:00:00.153095 s
# train loss: 0.116 | val loss: 0.558 | test loss: 1.248
# EarlyStopping counter: 15 out of 20
# epoch: 17
# 	iter:     0/   17 | loss: 0.192
# 	iter:    10/   17 | loss: 0.023
# epoch 17 time: 0:00:00.140631 s
# train loss: 0.098 | val loss: 0.738 | test loss: 1.379
# EarlyStopping counter: 16 out of 20
# epoch: 18
# 	iter:     0/   17 | loss: 0.057
# 	iter:    10/   17 | loss: 0.149
# epoch 18 time: 0:00:00.145068 s
# train loss: 0.101 | val loss: 0.640 | test loss: 1.527
# EarlyStopping counter: 17 out of 20
# epoch: 19
# 	iter:     0/   17 | loss: 0.476
# 	iter:    10/   17 | loss: 0.022
# epoch 19 time: 0:00:00.165652 s
# train loss: 0.101 | val loss: 0.623 | test loss: 1.224
# EarlyStopping counter: 18 out of 20
# epoch: 20
# 	iter:     0/   17 | loss: 0.064
# 	iter:    10/   17 | loss: 0.188
# epoch 20 time: 0:00:00.135233 s
# train loss: 0.117 | val loss: 0.503 | test loss: 1.198
# validation loss decreased (0.530 --> 0.503)
# saving model
# epoch: 21
# 	iter:     0/   17 | loss: 0.128
# 	iter:    10/   17 | loss: 0.146
# epoch 21 time: 0:00:00.204040 s
# train loss: 0.135 | val loss: 0.733 | test loss: 1.476
# EarlyStopping counter: 1 out of 20
# epoch: 22
# 	iter:     0/   17 | loss: 0.243
# 	iter:    10/   17 | loss: 0.105
# epoch 22 time: 0:00:00.171148 s
# train loss: 0.115 | val loss: 0.669 | test loss: 1.340
# EarlyStopping counter: 2 out of 20
# epoch: 23
# 	iter:     0/   17 | loss: 0.099
# 	iter:    10/   17 | loss: 0.150
# epoch 23 time: 0:00:00.174405 s
# train loss: 0.139 | val loss: 0.619 | test loss: 1.378
# EarlyStopping counter: 3 out of 20
# epoch: 24
# 	iter:     0/   17 | loss: 0.163
# 	iter:    10/   17 | loss: 0.131
# epoch 24 time: 0:00:00.180940 s
# train loss: 0.107 | val loss: 0.640 | test loss: 1.469
# EarlyStopping counter: 4 out of 20
# epoch: 25
# 	iter:     0/   17 | loss: 0.055
# 	iter:    10/   17 | loss: 0.153
# epoch 25 time: 0:00:00.145181 s
# train loss: 0.094 | val loss: 0.710 | test loss: 1.473
# EarlyStopping counter: 5 out of 20
# epoch: 26
# 	iter:     0/   17 | loss: 0.161
# 	iter:    10/   17 | loss: 0.070
# epoch 26 time: 0:00:00.135640 s
# train loss: 0.069 | val loss: 0.507 | test loss: 1.400
# EarlyStopping counter: 6 out of 20
# epoch: 27
# 	iter:     0/   17 | loss: 0.047
# 	iter:    10/   17 | loss: 0.120
# epoch 27 time: 0:00:00.135704 s
# train loss: 0.089 | val loss: 0.508 | test loss: 1.420
# EarlyStopping counter: 7 out of 20
# epoch: 28
# 	iter:     0/   17 | loss: 0.062
# 	iter:    10/   17 | loss: 0.044
# epoch 28 time: 0:00:00.152640 s
# train loss: 0.101 | val loss: 0.760 | test loss: 1.433
# EarlyStopping counter: 8 out of 20
# epoch: 29
# 	iter:     0/   17 | loss: 0.032
# 	iter:    10/   17 | loss: 0.144
# epoch 29 time: 0:00:00.140584 s
# train loss: 0.097 | val loss: 0.449 | test loss: 1.551
# validation loss decreased (0.503 --> 0.449)
# saving model
# epoch: 30
# 	iter:     0/   17 | loss: 0.025
# 	iter:    10/   17 | loss: 0.071
# epoch 30 time: 0:00:00.139674 s
# train loss: 0.091 | val loss: 0.738 | test loss: 1.512
# EarlyStopping counter: 1 out of 20
# epoch: 31
# 	iter:     0/   17 | loss: 0.055
# 	iter:    10/   17 | loss: 0.205
# epoch 31 time: 0:00:00.161525 s
# train loss: 0.083 | val loss: 0.500 | test loss: 1.548
# EarlyStopping counter: 2 out of 20
# epoch: 32
# 	iter:     0/   17 | loss: 0.066
# 	iter:    10/   17 | loss: 0.131
# epoch 32 time: 0:00:00.148626 s
# train loss: 0.106 | val loss: 0.505 | test loss: 1.541
# EarlyStopping counter: 3 out of 20
# epoch: 33
# 	iter:     0/   17 | loss: 0.045
# 	iter:    10/   17 | loss: 0.132
# epoch 33 time: 0:00:00.152948 s
# train loss: 0.079 | val loss: 0.731 | test loss: 1.624
# EarlyStopping counter: 4 out of 20
# epoch: 34
# 	iter:     0/   17 | loss: 0.033
# 	iter:    10/   17 | loss: 0.107
# epoch 34 time: 0:00:00.130617 s
# train loss: 0.083 | val loss: 0.737 | test loss: 1.556
# EarlyStopping counter: 5 out of 20
# epoch: 35
# 	iter:     0/   17 | loss: 0.091
# 	iter:    10/   17 | loss: 0.023
# epoch 35 time: 0:00:00.142063 s
# train loss: 0.082 | val loss: 0.621 | test loss: 1.558
# EarlyStopping counter: 6 out of 20
# epoch: 36
# 	iter:     0/   17 | loss: 0.014
# 	iter:    10/   17 | loss: 0.035
# epoch 36 time: 0:00:00.147677 s
# train loss: 0.071 | val loss: 0.592 | test loss: 1.540
# EarlyStopping counter: 7 out of 20
# epoch: 37
# 	iter:     0/   17 | loss: 0.030
# 	iter:    10/   17 | loss: 0.044
# epoch 37 time: 0:00:00.159043 s
# train loss: 0.094 | val loss: 0.501 | test loss: 1.522
# EarlyStopping counter: 8 out of 20
# epoch: 38
# 	iter:     0/   17 | loss: 0.061
# 	iter:    10/   17 | loss: 0.068
# epoch 38 time: 0:00:00.138516 s
# train loss: 0.089 | val loss: 0.741 | test loss: 1.523
# EarlyStopping counter: 9 out of 20
# epoch: 39
# 	iter:     0/   17 | loss: 0.071
# 	iter:    10/   17 | loss: 0.068
# epoch 39 time: 0:00:00.149140 s
# train loss: 0.077 | val loss: 0.908 | test loss: 1.599
# EarlyStopping counter: 10 out of 20
# epoch: 40
# 	iter:     0/   17 | loss: 0.038
# 	iter:    10/   17 | loss: 0.045
# epoch 40 time: 0:00:00.138556 s
# train loss: 0.069 | val loss: 0.750 | test loss: 1.592
# EarlyStopping counter: 11 out of 20
# epoch: 41
# 	iter:     0/   17 | loss: 0.082
# 	iter:    10/   17 | loss: 0.044
# epoch 41 time: 0:00:00.142528 s
# train loss: 0.069 | val loss: 0.866 | test loss: 1.519
# EarlyStopping counter: 12 out of 20
# epoch: 42
# 	iter:     0/   17 | loss: 0.036
# 	iter:    10/   17 | loss: 0.038
# epoch 42 time: 0:00:00.139680 s
# train loss: 0.074 | val loss: 0.887 | test loss: 1.621
# EarlyStopping counter: 13 out of 20
# epoch: 43
# 	iter:     0/   17 | loss: 0.055
# 	iter:    10/   17 | loss: 0.088
# epoch 43 time: 0:00:00.139560 s
# train loss: 0.071 | val loss: 0.529 | test loss: 1.526
# EarlyStopping counter: 14 out of 20
# epoch: 44
# 	iter:     0/   17 | loss: 0.076
# 	iter:    10/   17 | loss: 0.038
# epoch 44 time: 0:00:00.152965 s
# train loss: 0.079 | val loss: 0.511 | test loss: 1.494
# EarlyStopping counter: 15 out of 20
# epoch: 45
# 	iter:     0/   17 | loss: 0.146
# 	iter:    10/   17 | loss: 0.064
# epoch 45 time: 0:00:00.153562 s
# train loss: 0.074 | val loss: 0.747 | test loss: 1.475
# EarlyStopping counter: 16 out of 20
# epoch: 46
# 	iter:     0/   17 | loss: 0.058
# 	iter:    10/   17 | loss: 0.062
# epoch 46 time: 0:00:00.149072 s
# train loss: 0.073 | val loss: 0.609 | test loss: 1.479
# EarlyStopping counter: 17 out of 20
# epoch: 47
# 	iter:     0/   17 | loss: 0.060
# 	iter:    10/   17 | loss: 0.068
# epoch 47 time: 0:00:00.157739 s
# train loss: 0.067 | val loss: 0.615 | test loss: 1.578
# EarlyStopping counter: 18 out of 20
# epoch: 48
# 	iter:     0/   17 | loss: 0.018
# 	iter:    10/   17 | loss: 0.087
# epoch 48 time: 0:00:00.142134 s
# train loss: 0.072 | val loss: 0.625 | test loss: 1.569
# EarlyStopping counter: 19 out of 20
# epoch: 49
# 	iter:     0/   17 | loss: 0.051
# 	iter:    10/   17 | loss: 0.040
# epoch 49 time: 0:00:00.162739 s
# train loss: 0.064 | val loss: 0.843 | test loss: 1.485
# EarlyStopping counter: 20 out of 20
# early stopping!
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# epoch: 1
# 	iter:     0/   17 | loss: 0.813
# 	iter:    10/   17 | loss: 0.780
# epoch 1 time: 0:00:00.162695 s
# train loss: 0.813 | val loss: 0.834 | test loss: 1.333
# validation loss decreased (inf --> 0.834)
# saving model
# epoch: 2
# 	iter:     0/   17 | loss: 0.592
# 	iter:    10/   17 | loss: 0.178
# epoch 2 time: 0:00:00.152935 s
# train loss: 0.372 | val loss: 0.726 | test loss: 1.210
# validation loss decreased (0.834 --> 0.726)
# saving model
# epoch: 3
# 	iter:     0/   17 | loss: 0.072
# 	iter:    10/   17 | loss: 0.381
# epoch 3 time: 0:00:00.154038 s
# train loss: 0.219 | val loss: 0.705 | test loss: 1.726
# validation loss decreased (0.726 --> 0.705)
# saving model
# epoch: 4
# 	iter:     0/   17 | loss: 0.248
# 	iter:    10/   17 | loss: 0.048
# epoch 4 time: 0:00:00.273070 s
# train loss: 0.221 | val loss: 0.683 | test loss: 1.658
# validation loss decreased (0.705 --> 0.683)
# saving model
# epoch: 5
# 	iter:     0/   17 | loss: 0.066
# 	iter:    10/   17 | loss: 0.510
# epoch 5 time: 0:00:00.246321 s
# train loss: 0.208 | val loss: 0.785 | test loss: 1.426
# EarlyStopping counter: 1 out of 20
# epoch: 6
# 	iter:     0/   17 | loss: 0.126
# 	iter:    10/   17 | loss: 0.413
# epoch 6 time: 0:00:00.225047 s
# train loss: 0.227 | val loss: 0.722 | test loss: 1.645
# EarlyStopping counter: 2 out of 20
# epoch: 7
# 	iter:     0/   17 | loss: 0.453
# 	iter:    10/   17 | loss: 0.051
# epoch 7 time: 0:00:00.205052 s
# train loss: 0.234 | val loss: 0.581 | test loss: 1.438
# validation loss decreased (0.683 --> 0.581)
# saving model
# epoch: 8
# 	iter:     0/   17 | loss: 0.245
# 	iter:    10/   17 | loss: 0.081
# epoch 8 time: 0:00:00.269300 s
# train loss: 0.212 | val loss: 0.726 | test loss: 1.716
# EarlyStopping counter: 1 out of 20
# epoch: 9
# 	iter:     0/   17 | loss: 0.161
# 	iter:    10/   17 | loss: 0.109
# epoch 9 time: 0:00:00.198046 s
# train loss: 0.201 | val loss: 0.577 | test loss: 1.746
# validation loss decreased (0.581 --> 0.577)
# saving model
# epoch: 10
# 	iter:     0/   17 | loss: 0.362
# 	iter:    10/   17 | loss: 0.389
# epoch 10 time: 0:00:00.184083 s
# train loss: 0.219 | val loss: 0.564 | test loss: 1.584
# validation loss decreased (0.577 --> 0.564)
# saving model
# epoch: 11
# 	iter:     0/   17 | loss: 0.355
# 	iter:    10/   17 | loss: 0.110
# epoch 11 time: 0:00:00.153066 s
# train loss: 0.199 | val loss: 0.709 | test loss: 1.498
# EarlyStopping counter: 1 out of 20
# epoch: 12
# 	iter:     0/   17 | loss: 0.187
# 	iter:    10/   17 | loss: 0.046
# epoch 12 time: 0:00:00.154560 s
# train loss: 0.175 | val loss: 0.693 | test loss: 1.594
# EarlyStopping counter: 2 out of 20
# epoch: 13
# 	iter:     0/   17 | loss: 0.230
# 	iter:    10/   17 | loss: 0.051
# epoch 13 time: 0:00:00.163452 s
# train loss: 0.179 | val loss: 0.680 | test loss: 1.264
# EarlyStopping counter: 3 out of 20
# epoch: 14
# 	iter:     0/   17 | loss: 0.210
# 	iter:    10/   17 | loss: 0.299
# epoch 14 time: 0:00:00.195043 s
# train loss: 0.164 | val loss: 0.609 | test loss: 1.543
# EarlyStopping counter: 4 out of 20
# epoch: 15
# 	iter:     0/   17 | loss: 0.066
# 	iter:    10/   17 | loss: 0.074
# epoch 15 time: 0:00:00.166521 s
# train loss: 0.147 | val loss: 0.693 | test loss: 1.521
# EarlyStopping counter: 5 out of 20
# epoch: 16
# 	iter:     0/   17 | loss: 0.293
# 	iter:    10/   17 | loss: 0.265
# epoch 16 time: 0:00:00.141059 s
# train loss: 0.206 | val loss: 0.417 | test loss: 1.316
# validation loss decreased (0.564 --> 0.417)
# saving model
# epoch: 17
# 	iter:     0/   17 | loss: 0.216
# 	iter:    10/   17 | loss: 0.064
# epoch 17 time: 0:00:00.158068 s
# train loss: 0.155 | val loss: 0.749 | test loss: 1.423
# EarlyStopping counter: 1 out of 20
# epoch: 18
# 	iter:     0/   17 | loss: 0.236
# 	iter:    10/   17 | loss: 0.309
# epoch 18 time: 0:00:00.171529 s
# train loss: 0.146 | val loss: 0.755 | test loss: 1.560
# EarlyStopping counter: 2 out of 20
# epoch: 19
# 	iter:     0/   17 | loss: 0.417
# 	iter:    10/   17 | loss: 0.094
# epoch 19 time: 0:00:00.152049 s
# train loss: 0.145 | val loss: 0.767 | test loss: 1.104
# EarlyStopping counter: 3 out of 20
# epoch: 20
# 	iter:     0/   17 | loss: 0.093
# 	iter:    10/   17 | loss: 0.273
# epoch 20 time: 0:00:00.153562 s
# train loss: 0.138 | val loss: 0.579 | test loss: 1.169
# EarlyStopping counter: 4 out of 20
# epoch: 21
# 	iter:     0/   17 | loss: 0.141
# 	iter:    10/   17 | loss: 0.033
# epoch 21 time: 0:00:00.151029 s
# train loss: 0.162 | val loss: 0.784 | test loss: 1.478
# EarlyStopping counter: 5 out of 20
# epoch: 22
# 	iter:     0/   17 | loss: 0.126
# 	iter:    10/   17 | loss: 0.109
# epoch 22 time: 0:00:00.150538 s
# train loss: 0.130 | val loss: 0.672 | test loss: 1.225
# EarlyStopping counter: 6 out of 20
# epoch: 23
# 	iter:     0/   17 | loss: 0.167
# 	iter:    10/   17 | loss: 0.154
# epoch 23 time: 0:00:00.156784 s
# train loss: 0.171 | val loss: 0.521 | test loss: 1.495
# EarlyStopping counter: 7 out of 20
# epoch: 24
# 	iter:     0/   17 | loss: 0.233
# 	iter:    10/   17 | loss: 0.046
# epoch 24 time: 0:00:00.163056 s
# train loss: 0.131 | val loss: 0.630 | test loss: 1.435
# EarlyStopping counter: 8 out of 20
# epoch: 25
# 	iter:     0/   17 | loss: 0.063
# 	iter:    10/   17 | loss: 0.123
# epoch 25 time: 0:00:00.156525 s
# train loss: 0.110 | val loss: 0.580 | test loss: 1.417
# EarlyStopping counter: 9 out of 20
# epoch: 26
# 	iter:     0/   17 | loss: 0.143
# 	iter:    10/   17 | loss: 0.033
# epoch 26 time: 0:00:00.148606 s
# train loss: 0.089 | val loss: 0.690 | test loss: 1.330
# EarlyStopping counter: 10 out of 20
# epoch: 27
# 	iter:     0/   17 | loss: 0.065
# 	iter:    10/   17 | loss: 0.034
# epoch 27 time: 0:00:00.150539 s
# train loss: 0.150 | val loss: 0.596 | test loss: 1.360
# EarlyStopping counter: 11 out of 20
# epoch: 28
# 	iter:     0/   17 | loss: 0.108
# 	iter:    10/   17 | loss: 0.037
# epoch 28 time: 0:00:00.155032 s
# train loss: 0.100 | val loss: 0.756 | test loss: 1.318
# EarlyStopping counter: 12 out of 20
# epoch: 29
# 	iter:     0/   17 | loss: 0.034
# 	iter:    10/   17 | loss: 0.269
# epoch 29 time: 0:00:00.162073 s
# train loss: 0.106 | val loss: 0.750 | test loss: 1.505
# EarlyStopping counter: 13 out of 20
# epoch: 30
# 	iter:     0/   17 | loss: 0.068
# 	iter:    10/   17 | loss: 0.063
# epoch 30 time: 0:00:00.162526 s
# train loss: 0.108 | val loss: 0.671 | test loss: 1.148
# EarlyStopping counter: 14 out of 20
# epoch: 31
# 	iter:     0/   17 | loss: 0.059
# 	iter:    10/   17 | loss: 0.209
# epoch 31 time: 0:00:00.162097 s
# train loss: 0.102 | val loss: 0.788 | test loss: 1.512
# EarlyStopping counter: 15 out of 20
# epoch: 32
# 	iter:     0/   17 | loss: 0.061
# 	iter:    10/   17 | loss: 0.447
# epoch 32 time: 0:00:00.161079 s
# train loss: 0.210 | val loss: 0.792 | test loss: 1.636
# EarlyStopping counter: 16 out of 20
# epoch: 33
# 	iter:     0/   17 | loss: 0.149
# 	iter:    10/   17 | loss: 0.128
# epoch 33 time: 0:00:00.163161 s
# train loss: 0.137 | val loss: 0.858 | test loss: 1.324
# EarlyStopping counter: 17 out of 20
# epoch: 34
# 	iter:     0/   17 | loss: 0.103
# 	iter:    10/   17 | loss: 0.136
# epoch 34 time: 0:00:00.138183 s
# train loss: 0.124 | val loss: 0.695 | test loss: 1.476
# EarlyStopping counter: 18 out of 20
# epoch: 35
# 	iter:     0/   17 | loss: 0.053
# 	iter:    10/   17 | loss: 0.062
# epoch 35 time: 0:00:00.160551 s
# train loss: 0.166 | val loss: 0.674 | test loss: 1.362
# EarlyStopping counter: 19 out of 20
# epoch: 36
# 	iter:     0/   17 | loss: 0.027
# 	iter:    10/   17 | loss: 0.048
# epoch 36 time: 0:00:00.173048 s
# train loss: 0.139 | val loss: 0.674 | test loss: 1.455
# EarlyStopping counter: 20 out of 20
# early stopping!
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# epoch: 1
# 	iter:     0/   17 | loss: 0.815
# 	iter:    10/   17 | loss: 0.838
# epoch 1 time: 0:00:00.259645 s
# train loss: 0.857 | val loss: 0.543 | test loss: 1.808
# validation loss decreased (inf --> 0.543)
# saving model
# epoch: 2
# 	iter:     0/   17 | loss: 0.659
# 	iter:    10/   17 | loss: 0.212
# epoch 2 time: 0:00:00.217067 s
# train loss: 0.447 | val loss: 0.825 | test loss: 1.915
# EarlyStopping counter: 1 out of 20
# epoch: 3
# 	iter:     0/   17 | loss: 0.078
# 	iter:    10/   17 | loss: 0.471
# epoch 3 time: 0:00:00.207309 s
# train loss: 0.240 | val loss: 0.928 | test loss: 2.191
# EarlyStopping counter: 2 out of 20
# epoch: 4
# 	iter:     0/   17 | loss: 0.247
# 	iter:    10/   17 | loss: 0.113
# epoch 4 time: 0:00:00.187530 s
# train loss: 0.241 | val loss: 0.944 | test loss: 1.802
# EarlyStopping counter: 3 out of 20
# epoch: 5
# 	iter:     0/   17 | loss: 0.162
# 	iter:    10/   17 | loss: 0.588
# epoch 5 time: 0:00:00.221085 s
# train loss: 0.239 | val loss: 0.940 | test loss: 2.200
# EarlyStopping counter: 4 out of 20
# epoch: 6
# 	iter:     0/   17 | loss: 0.108
# 	iter:    10/   17 | loss: 0.345
# epoch 6 time: 0:00:00.179052 s
# train loss: 0.231 | val loss: 1.028 | test loss: 2.061
# EarlyStopping counter: 5 out of 20
# epoch: 7
# 	iter:     0/   17 | loss: 0.320
# 	iter:    10/   17 | loss: 0.081
# epoch 7 time: 0:00:00.186103 s
# train loss: 0.218 | val loss: 0.739 | test loss: 2.190
# EarlyStopping counter: 6 out of 20
# epoch: 8
# 	iter:     0/   17 | loss: 0.409
# 	iter:    10/   17 | loss: 0.122
# epoch 8 time: 0:00:00.155711 s
# train loss: 0.235 | val loss: 1.048 | test loss: 2.161
# EarlyStopping counter: 7 out of 20
# epoch: 9
# 	iter:     0/   17 | loss: 0.198
# 	iter:    10/   17 | loss: 0.098
# epoch 9 time: 0:00:00.127968 s
# train loss: 0.185 | val loss: 0.803 | test loss: 2.486
# EarlyStopping counter: 8 out of 20
# epoch: 10
# 	iter:     0/   17 | loss: 0.369
# 	iter:    10/   17 | loss: 0.324
# epoch 10 time: 0:00:00.163104 s
# train loss: 0.225 | val loss: 0.858 | test loss: 2.177
# EarlyStopping counter: 9 out of 20
# epoch: 11
# 	iter:     0/   17 | loss: 0.366
# 	iter:    10/   17 | loss: 0.083
# epoch 11 time: 0:00:00.159691 s
# train loss: 0.212 | val loss: 1.098 | test loss: 1.999
# EarlyStopping counter: 10 out of 20
# epoch: 12
# 	iter:     0/   17 | loss: 0.166
# 	iter:    10/   17 | loss: 0.034
# epoch 12 time: 0:00:00.164940 s
# train loss: 0.182 | val loss: 0.996 | test loss: 2.087
# EarlyStopping counter: 11 out of 20
# epoch: 13
# 	iter:     0/   17 | loss: 0.309
# 	iter:    10/   17 | loss: 0.030
# epoch 13 time: 0:00:00.155073 s
# train loss: 0.180 | val loss: 1.054 | test loss: 1.974
# EarlyStopping counter: 12 out of 20
# epoch: 14
# 	iter:     0/   17 | loss: 0.293
# 	iter:    10/   17 | loss: 0.297
# epoch 14 time: 0:00:00.166540 s
# train loss: 0.194 | val loss: 0.858 | test loss: 2.009
# EarlyStopping counter: 13 out of 20
# epoch: 15
# 	iter:     0/   17 | loss: 0.044
# 	iter:    10/   17 | loss: 0.021
# epoch 15 time: 0:00:00.165018 s
# train loss: 0.181 | val loss: 1.085 | test loss: 2.015
# EarlyStopping counter: 14 out of 20
# epoch: 16
# 	iter:     0/   17 | loss: 0.308
# 	iter:    10/   17 | loss: 0.192
# epoch 16 time: 0:00:00.219978 s
# train loss: 0.161 | val loss: 0.801 | test loss: 1.995
# EarlyStopping counter: 15 out of 20
# epoch: 17
# 	iter:     0/   17 | loss: 0.129
# 	iter:    10/   17 | loss: 0.040
# epoch 17 time: 0:00:00.206074 s
# train loss: 0.142 | val loss: 1.125 | test loss: 1.998
# EarlyStopping counter: 16 out of 20
# epoch: 18
# 	iter:     0/   17 | loss: 0.233
# 	iter:    10/   17 | loss: 0.287
# epoch 18 time: 0:00:00.141954 s
# train loss: 0.164 | val loss: 0.884 | test loss: 2.142
# EarlyStopping counter: 17 out of 20
# epoch: 19
# 	iter:     0/   17 | loss: 0.435
# 	iter:    10/   17 | loss: 0.138
# epoch 19 time: 0:00:00.178655 s
# train loss: 0.152 | val loss: 1.107 | test loss: 1.876
# EarlyStopping counter: 18 out of 20
# epoch: 20
# 	iter:     0/   17 | loss: 0.071
# 	iter:    10/   17 | loss: 0.254
# epoch 20 time: 0:00:00.167434 s
# train loss: 0.162 | val loss: 0.935 | test loss: 1.840
# EarlyStopping counter: 19 out of 20
# epoch: 21
# 	iter:     0/   17 | loss: 0.127
# 	iter:    10/   17 | loss: 0.158
# epoch 21 time: 0:00:00.161064 s
# train loss: 0.160 | val loss: 1.048 | test loss: 1.981
# EarlyStopping counter: 20 out of 20
# early stopping!
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# epoch: 1
# 	iter:     0/   17 | loss: 0.768
# 	iter:    10/   17 | loss: 0.711
# epoch 1 time: 0:00:00.183136 s
# train loss: 0.730 | val loss: 0.618 | test loss: 0.933
# validation loss decreased (inf --> 0.618)
# saving model
# epoch: 2
# 	iter:     0/   17 | loss: 0.354
# 	iter:    10/   17 | loss: 0.201
# epoch 2 time: 0:00:00.166526 s
# train loss: 0.235 | val loss: 0.684 | test loss: 0.980
# EarlyStopping counter: 1 out of 20
# epoch: 3
# 	iter:     0/   17 | loss: 0.328
# 	iter:    10/   17 | loss: 0.385
# epoch 3 time: 0:00:00.182578 s
# train loss: 0.203 | val loss: 0.747 | test loss: 1.045
# EarlyStopping counter: 2 out of 20
# epoch: 4
# 	iter:     0/   17 | loss: 0.133
# 	iter:    10/   17 | loss: 0.044
# epoch 4 time: 0:00:00.187087 s
# train loss: 0.182 | val loss: 0.764 | test loss: 1.065
# EarlyStopping counter: 3 out of 20
# epoch: 5
# 	iter:     0/   17 | loss: 0.088
# 	iter:    10/   17 | loss: 0.470
# epoch 5 time: 0:00:00.150284 s
# train loss: 0.189 | val loss: 0.695 | test loss: 0.941
# EarlyStopping counter: 4 out of 20
# epoch: 6
# 	iter:     0/   17 | loss: 0.100
# 	iter:    10/   17 | loss: 0.267
# epoch 6 time: 0:00:00.153832 s
# train loss: 0.182 | val loss: 0.784 | test loss: 1.052
# EarlyStopping counter: 5 out of 20
# epoch: 7
# 	iter:     0/   17 | loss: 0.251
# 	iter:    10/   17 | loss: 0.112
# epoch 7 time: 0:00:00.172072 s
# train loss: 0.194 | val loss: 0.868 | test loss: 1.123
# EarlyStopping counter: 6 out of 20
# epoch: 8
# 	iter:     0/   17 | loss: 0.347
# 	iter:    10/   17 | loss: 0.113
# epoch 8 time: 0:00:00.187140 s
# train loss: 0.189 | val loss: 0.901 | test loss: 1.203
# EarlyStopping counter: 7 out of 20
# epoch: 9
# 	iter:     0/   17 | loss: 0.132
# 	iter:    10/   17 | loss: 0.054
# epoch 9 time: 0:00:00.173133 s
# train loss: 0.160 | val loss: 0.975 | test loss: 1.206
# EarlyStopping counter: 8 out of 20
# epoch: 10
# 	iter:     0/   17 | loss: 0.316
# 	iter:    10/   17 | loss: 0.329
# epoch 10 time: 0:00:00.157549 s
# train loss: 0.208 | val loss: 1.052 | test loss: 1.323
# EarlyStopping counter: 9 out of 20
# epoch: 11
# 	iter:     0/   17 | loss: 0.317
# 	iter:    10/   17 | loss: 0.067
# epoch 11 time: 0:00:00.163155 s
# train loss: 0.185 | val loss: 0.865 | test loss: 1.158
# EarlyStopping counter: 10 out of 20
# epoch: 12
# 	iter:     0/   17 | loss: 0.064
# 	iter:    10/   17 | loss: 0.057
# epoch 12 time: 0:00:00.177054 s
# train loss: 0.154 | val loss: 0.854 | test loss: 1.157
# EarlyStopping counter: 11 out of 20
# epoch: 13
# 	iter:     0/   17 | loss: 0.299
# 	iter:    10/   17 | loss: 0.060
# epoch 13 time: 0:00:00.188093 s
# train loss: 0.170 | val loss: 0.803 | test loss: 1.077
# EarlyStopping counter: 12 out of 20
# epoch: 14
# 	iter:     0/   17 | loss: 0.295
# 	iter:    10/   17 | loss: 0.123
# epoch 14 time: 0:00:00.178602 s
# train loss: 0.159 | val loss: 0.875 | test loss: 1.065
# EarlyStopping counter: 13 out of 20
# epoch: 15
# 	iter:     0/   17 | loss: 0.047
# 	iter:    10/   17 | loss: 0.105
# epoch 15 time: 0:00:00.175575 s
# train loss: 0.174 | val loss: 0.943 | test loss: 1.294
# EarlyStopping counter: 14 out of 20
# epoch: 16
# 	iter:     0/   17 | loss: 0.349
# 	iter:    10/   17 | loss: 0.135
# epoch 16 time: 0:00:00.188198 s
# train loss: 0.150 | val loss: 0.934 | test loss: 1.172
# EarlyStopping counter: 15 out of 20
# epoch: 17
# 	iter:     0/   17 | loss: 0.044
# 	iter:    10/   17 | loss: 0.045
# epoch 17 time: 0:00:00.193010 s
# train loss: 0.138 | val loss: 0.902 | test loss: 1.201
# EarlyStopping counter: 16 out of 20
# epoch: 18
# 	iter:     0/   17 | loss: 0.203
# 	iter:    10/   17 | loss: 0.281
# epoch 18 time: 0:00:00.188120 s
# train loss: 0.162 | val loss: 0.959 | test loss: 1.267
# EarlyStopping counter: 17 out of 20
# epoch: 19
# 	iter:     0/   17 | loss: 0.403
# 	iter:    10/   17 | loss: 0.174
# epoch 19 time: 0:00:00.196068 s
# train loss: 0.125 | val loss: 0.905 | test loss: 1.207
# EarlyStopping counter: 18 out of 20
# epoch: 20
# 	iter:     0/   17 | loss: 0.035
# 	iter:    10/   17 | loss: 0.243
# epoch 20 time: 0:00:00.215051 s
# train loss: 0.115 | val loss: 0.950 | test loss: 1.207
# EarlyStopping counter: 19 out of 20
# epoch: 21
# 	iter:     0/   17 | loss: 0.041
# 	iter:    10/   17 | loss: 0.105
# epoch 21 time: 0:00:00.184064 s
# train loss: 0.106 | val loss: 0.880 | test loss: 1.192
# EarlyStopping counter: 20 out of 20
# early stopping!
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# epoch: 1
# 	iter:     0/   17 | loss: 0.810
# 	iter:    10/   17 | loss: 0.786
# epoch 1 time: 0:00:00.216151 s
# train loss: 0.821 | val loss: 1.253 | test loss: 1.436
# validation loss decreased (inf --> 1.253)
# saving model
# epoch: 2
# 	iter:     0/   17 | loss: 0.541
# 	iter:    10/   17 | loss: 0.268
# epoch 2 time: 0:00:00.314674 s
# train loss: 0.295 | val loss: 1.546 | test loss: 1.817
# EarlyStopping counter: 1 out of 20
# epoch: 3
# 	iter:     0/   17 | loss: 0.282
# 	iter:    10/   17 | loss: 0.375
# epoch 3 time: 0:00:00.209094 s
# train loss: 0.233 | val loss: 1.510 | test loss: 1.986
# EarlyStopping counter: 2 out of 20
# epoch: 4
# 	iter:     0/   17 | loss: 0.239
# 	iter:    10/   17 | loss: 0.051
# epoch 4 time: 0:00:00.217098 s
# train loss: 0.212 | val loss: 1.397 | test loss: 1.880
# EarlyStopping counter: 3 out of 20
# epoch: 5
# 	iter:     0/   17 | loss: 0.165
# 	iter:    10/   17 | loss: 0.533
# epoch 5 time: 0:00:00.254641 s
# train loss: 0.219 | val loss: 1.544 | test loss: 1.820
# EarlyStopping counter: 4 out of 20
# epoch: 6
# 	iter:     0/   17 | loss: 0.138
# 	iter:    10/   17 | loss: 0.333
# epoch 6 time: 0:00:00.243062 s
# train loss: 0.229 | val loss: 1.610 | test loss: 1.988
# EarlyStopping counter: 5 out of 20
# epoch: 7
# 	iter:     0/   17 | loss: 0.343
# 	iter:    10/   17 | loss: 0.101
# epoch 7 time: 0:00:00.235101 s
# train loss: 0.219 | val loss: 1.638 | test loss: 1.980
# EarlyStopping counter: 6 out of 20
# epoch: 8
# 	iter:     0/   17 | loss: 0.232
# 	iter:    10/   17 | loss: 0.109
# epoch 8 time: 0:00:00.214259 s
# train loss: 0.211 | val loss: 1.595 | test loss: 1.959
# EarlyStopping counter: 7 out of 20
# epoch: 9
# 	iter:     0/   17 | loss: 0.130
# 	iter:    10/   17 | loss: 0.119
# epoch 9 time: 0:00:00.184559 s
# train loss: 0.202 | val loss: 1.583 | test loss: 2.071
# EarlyStopping counter: 8 out of 20
# epoch: 10
# 	iter:     0/   17 | loss: 0.382
# 	iter:    10/   17 | loss: 0.402
# epoch 10 time: 0:00:00.176152 s
# train loss: 0.223 | val loss: 1.608 | test loss: 1.986
# EarlyStopping counter: 9 out of 20
# epoch: 11
# 	iter:     0/   17 | loss: 0.365
# 	iter:    10/   17 | loss: 0.100
# epoch 11 time: 0:00:00.210065 s
# train loss: 0.224 | val loss: 1.395 | test loss: 1.945
# EarlyStopping counter: 10 out of 20
# epoch: 12
# 	iter:     0/   17 | loss: 0.155
# 	iter:    10/   17 | loss: 0.067
# epoch 12 time: 0:00:00.153029 s
# train loss: 0.186 | val loss: 1.615 | test loss: 1.960
# EarlyStopping counter: 11 out of 20
# epoch: 13
# 	iter:     0/   17 | loss: 0.353
# 	iter:    10/   17 | loss: 0.067
# epoch 13 time: 0:00:00.157044 s
# train loss: 0.193 | val loss: 1.473 | test loss: 1.837
# EarlyStopping counter: 12 out of 20
# epoch: 14
# 	iter:     0/   17 | loss: 0.349
# 	iter:    10/   17 | loss: 0.215
# epoch 14 time: 0:00:00.158528 s
# train loss: 0.203 | val loss: 1.491 | test loss: 1.976
# EarlyStopping counter: 13 out of 20
# epoch: 15
# 	iter:     0/   17 | loss: 0.065
# 	iter:    10/   17 | loss: 0.030
# epoch 15 time: 0:00:00.205045 s
# train loss: 0.198 | val loss: 1.606 | test loss: 2.063
# EarlyStopping counter: 14 out of 20
# epoch: 16
# 	iter:     0/   17 | loss: 0.470
# 	iter:    10/   17 | loss: 0.165
# epoch 16 time: 0:00:00.157035 s
# train loss: 0.194 | val loss: 1.419 | test loss: 1.790
# EarlyStopping counter: 15 out of 20
# epoch: 17
# 	iter:     0/   17 | loss: 0.145
# 	iter:    10/   17 | loss: 0.047
# epoch 17 time: 0:00:00.151515 s
# train loss: 0.199 | val loss: 1.174 | test loss: 1.866
# validation loss decreased (1.253 --> 1.174)
# saving model
# epoch: 18
# 	iter:     0/   17 | loss: 0.328
# 	iter:    10/   17 | loss: 0.365
# epoch 18 time: 0:00:00.150028 s
# train loss: 0.202 | val loss: 1.596 | test loss: 1.871
# EarlyStopping counter: 1 out of 20
# epoch: 19
# 	iter:     0/   17 | loss: 0.367
# 	iter:    10/   17 | loss: 0.310
# epoch 19 time: 0:00:00.147522 s
# train loss: 0.206 | val loss: 1.541 | test loss: 2.079
# EarlyStopping counter: 2 out of 20
# epoch: 20
# 	iter:     0/   17 | loss: 0.082
# 	iter:    10/   17 | loss: 0.142
# epoch 20 time: 0:00:00.149174 s
# train loss: 0.184 | val loss: 1.574 | test loss: 1.996
# EarlyStopping counter: 3 out of 20
# epoch: 21
# 	iter:     0/   17 | loss: 0.084
# 	iter:    10/   17 | loss: 0.163
# epoch 21 time: 0:00:00.146672 s
# train loss: 0.212 | val loss: 1.435 | test loss: 1.807
# EarlyStopping counter: 4 out of 20
# epoch: 22
# 	iter:     0/   17 | loss: 0.122
# 	iter:    10/   17 | loss: 0.188
# epoch 22 time: 0:00:00.146058 s
# train loss: 0.206 | val loss: 1.449 | test loss: 1.832
# EarlyStopping counter: 5 out of 20
# epoch: 23
# 	iter:     0/   17 | loss: 0.090
# 	iter:    10/   17 | loss: 0.310
# epoch 23 time: 0:00:00.142645 s
# train loss: 0.198 | val loss: 1.634 | test loss: 2.154
# EarlyStopping counter: 6 out of 20
# epoch: 24
# 	iter:     0/   17 | loss: 0.239
# 	iter:    10/   17 | loss: 0.351
# epoch 24 time: 0:00:00.144836 s
# train loss: 0.188 | val loss: 1.607 | test loss: 1.945
# EarlyStopping counter: 7 out of 20
# epoch: 25
# 	iter:     0/   17 | loss: 0.047
# 	iter:    10/   17 | loss: 0.139
# epoch 25 time: 0:00:00.148606 s
# train loss: 0.171 | val loss: 1.566 | test loss: 1.972
# EarlyStopping counter: 8 out of 20
# epoch: 26
# 	iter:     0/   17 | loss: 0.099
# 	iter:    10/   17 | loss: 0.138
# epoch 26 time: 0:00:00.154642 s
# train loss: 0.157 | val loss: 1.615 | test loss: 1.997
# EarlyStopping counter: 9 out of 20
# epoch: 27
# 	iter:     0/   17 | loss: 0.081
# 	iter:    10/   17 | loss: 0.067
# epoch 27 time: 0:00:00.176122 s
# train loss: 0.155 | val loss: 1.661 | test loss: 1.985
# EarlyStopping counter: 10 out of 20
# epoch: 28
# 	iter:     0/   17 | loss: 0.040
# 	iter:    10/   17 | loss: 0.211
# epoch 28 time: 0:00:00.186990 s
# train loss: 0.147 | val loss: 1.722 | test loss: 2.077
# EarlyStopping counter: 11 out of 20
# epoch: 29
# 	iter:     0/   17 | loss: 0.040
# 	iter:    10/   17 | loss: 0.155
# epoch 29 time: 0:00:00.187587 s
# train loss: 0.167 | val loss: 1.554 | test loss: 1.952
# EarlyStopping counter: 12 out of 20
# epoch: 30
# 	iter:     0/   17 | loss: 0.065
# 	iter:    10/   17 | loss: 0.095
# epoch 30 time: 0:00:00.212900 s
# train loss: 0.133 | val loss: 1.780 | test loss: 2.013
# EarlyStopping counter: 13 out of 20
# epoch: 31
# 	iter:     0/   17 | loss: 0.063
# 	iter:    10/   17 | loss: 0.134
# epoch 31 time: 0:00:00.169637 s
# train loss: 0.151 | val loss: 1.639 | test loss: 2.011
# EarlyStopping counter: 14 out of 20
# epoch: 32
# 	iter:     0/   17 | loss: 0.136
# 	iter:    10/   17 | loss: 0.151
# epoch 32 time: 0:00:00.147142 s
# train loss: 0.125 | val loss: 1.732 | test loss: 2.062
# EarlyStopping counter: 15 out of 20
# epoch: 33
# 	iter:     0/   17 | loss: 0.135
# 	iter:    10/   17 | loss: 0.090
# epoch 33 time: 0:00:00.143592 s
# train loss: 0.111 | val loss: 1.762 | test loss: 2.058
# EarlyStopping counter: 16 out of 20
# epoch: 34
# 	iter:     0/   17 | loss: 0.079
# 	iter:    10/   17 | loss: 0.090
# epoch 34 time: 0:00:00.145076 s
# train loss: 0.098 | val loss: 1.608 | test loss: 2.045
# EarlyStopping counter: 17 out of 20
# epoch: 35
# 	iter:     0/   17 | loss: 0.140
# 	iter:    10/   17 | loss: 0.051
# epoch 35 time: 0:00:00.135534 s
# train loss: 0.087 | val loss: 1.591 | test loss: 2.162
# EarlyStopping counter: 18 out of 20
# epoch: 36
# 	iter:     0/   17 | loss: 0.050
# 	iter:    10/   17 | loss: 0.043
# epoch 36 time: 0:00:00.143854 s
# train loss: 0.068 | val loss: 1.529 | test loss: 2.043
# EarlyStopping counter: 19 out of 20
# epoch: 37
# 	iter:     0/   17 | loss: 0.078
# 	iter:    10/   17 | loss: 0.083
# epoch 37 time: 0:00:00.137630 s
# train loss: 0.102 | val loss: 1.767 | test loss: 1.992
# EarlyStopping counter: 20 out of 20
# early stopping!
# c:\Users\iokhotnikov\Documents\Python\bidding_engine\.venv\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
