# %% [markdown]
# # <a id='toc1_'></a>[Forecasting (PyTorch)](#toc0_)

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Forecasting (PyTorch)](#toc1_)
#   - [Bidding dataset class](#toc1_1_)
#   - [LSTM model class](#toc1_2_)
#   - [Early stopping class](#toc1_3_)
#   - [Experiment class](#toc1_4_)
#   - [Parameters](#toc1_5_)
#   - [Model](#toc1_6_)
#   - [Training](#toc1_7_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ## <a id='toc1_1_'></a>[Bidding dataset class](#toc0_)

# %%
from torch.utils.data import Dataset, DataLoader

from sklearn.preprocessing import StandardScaler


class BiddingData(Dataset):

    def __init__(self,
                 seq_len: int,
                 pred_len: int,
                 scale: bool,
                 flag: str,
                 val_split: float,
                 test_split: float,
                 cluster: int,
                 features: list,
                 target: str | None = None) -> None:
        assert flag in ['train', 'test', 'val', 'pred']
        assert target
        assert features
        self.flag = flag
        type_map = {'train': 0, 'val': 1, 'test': 2}
        self.set_type = type_map[self.flag]
        self.seq_len = seq_len
        self.pred_len = pred_len
        self.val_split = val_split
        self.test_split = test_split
        self.target = target
        self.features = features
        self.scale = scale
        self.cluster = cluster
        self.__read_data__()

    def __len__(self) -> int:
        return len(self.x) - self.seq_len - self.pred_len + 1

    def __read_data__(self) -> pd.DataFrame:
        cluster_df = pd.read_csv(
            os.path.join(os.environ['PROCESSED_DATA_PATH'],
                         f'processed_{self.cluster}.csv'))
        size = len(cluster_df)
        border1s = [
            0,
            int(size * (1 - self.val_split - self.test_split)),
            int(size * (1 - self.test_split))
        ]
        border2s = [
            int(size * (1 - self.val_split - self.test_split)),
            int(size * (1 - self.test_split)), size
        ]
        border1 = border1s[self.set_type]
        border2 = border2s[self.set_type]
        self.forecast_features = cluster_df.columns
        self.dataset = cluster_df.loc[border1:border2, features + [target]]
        self.data = self.dataset.values
        self.y = cluster_df.loc[border1:border2,
                                self.target].values.reshape(-1, 1)
        self.x = cluster_df.loc[border1:border2, self.features].values

        if self.scale:
            self.scaler = StandardScaler()
            train_data = cluster_df.loc[border1s[0]:border2s[0],
                                        features + [target]]
            self.scaler.fit(train_data)
            self.data = self.scaler.transform(self.dataset.values)
            self.x = pd.DataFrame(data=self.data,
                                  columns=features + [target])[features].values
            self.y = pd.DataFrame(data=self.data, columns=features +
                                  [target])[target].values.reshape(-1, 1)

    def __getitem__(self, index: int):
        x_begin = index
        x_end = x_begin + self.seq_len
        y_begin = x_end
        y_end = y_begin + self.pred_len
        seq_x = self.x[x_begin:x_end]
        seq_y = self.y[y_begin:y_end]
        return seq_x, seq_y

    def inverse_transform(self, data):
        return self.scaler.inverse_transform(data)

# %% [markdown]
# ## <a id='toc1_2_'></a>[LSTM model class](#toc0_)

# %%
import torch
from torch import nn


class LSTM(nn.Module):

    def __init__(self, input_size: int, hidden_size: int, num_layers: int,
                 batch_size: int, output_size: int, **kwargs):
        super(LSTM, self).__init__()
        # rnn = nn.LSTM(input_size=10, hidden_size=20, num_layers=2) # input_size - number of expected features in the input x, hidden_size -  number of features in the hidden state h

        # Inputs:
        # input = torch.randn(5, 3, 10) # [batch_size, input_size] for unbatched input, [seq_len, batch_size, input_size] when batch_first=False, [batch_size, seq_len, input_size] when batch_first=True

        # h0 = torch.randn(2, 3, 20) # [D * num_layers, hidden_size] for unbatched input, [D * num_layers, barch_size, hidden_size] , D = 2 if birectional=True, otherwise 1
        # c0 = torch.randn(2, 3, 20)
        # output, (hn, cn) = rnn(input, (h0, c0))
        self.input_size = input_size  # number of expected features in the input
        self.hidden_size = hidden_size  # number of features in the hidden state
        self.output_size = output_size
        self.num_layers = num_layers
        self.batch_size = batch_size
        self.lstm = nn.LSTM(input_size=self.input_size,
                            hidden_size=self.hidden_size,
                            num_layers=self.num_layers,
                            batch_first=True,
                            dtype=torch.float)
        self.linear = nn.Linear(self.hidden_size,
                                self.output_size,
                                dtype=torch.float)
        self.h0 = torch.randn(self.num_layers,
                              self.batch_size,
                              self.hidden_size,
                              dtype=torch.float)
        self.c0 = torch.randn(self.num_layers,
                              self.batch_size,
                              self.hidden_size,
                              dtype=torch.float)

    def forward(self, input):
        # input [self.batch_size, self.seq_len, self.input_size]
        output, (hn, cn) = self.lstm(input, (self.h0, self.c0))
        output = self.linear(output)
        return output

# %% [markdown]
# ## <a id='toc1_3_'></a>[Early stopping class](#toc0_)

# %%
import torch
from torch import optim
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime


class EarlyStopping:

    def __init__(self, patience: int, verbose: bool = True, delta: int = 0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = float('inf')
        self.delta = delta

    def __call__(self, val_loss, model, path='./runs'):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.path = os.path.join(path)
            self.save_checkpoint(val_loss, model, self.path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(
                f'EarlyStopping counter: {self.counter} out of {self.patience}'
            )
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, self.path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(
                f'validation loss decreased ({self.val_loss_min:.3f} --> {val_loss:.3f})',
                'saving model',
                sep='\n')
        os.makedirs(path, exist_ok=True)
        torch.save(model, os.path.join(path, 'checkpoint.pth'))
        self.val_loss_min = val_loss

# %% [markdown]
# ## <a id='toc1_4_'></a>[Experiment class](#toc0_)

# %%
class Experiment:

    def __init__(self, args):
        self.args = args
        torch.manual_seed(self.args['seed'])

    def _select_criterion(self):
        return nn.MSELoss()

    def _select_optimizer(self):
        return optim.Adam(self.model.parameters(),
                          lr=self.args['learning_rate'])

    def _get_data(self, flag):
        if flag in ['test', 'pred']:
            shuffle_flag = False
        else:
            shuffle_flag = True
        data = BiddingData(seq_len=self.args['seq_len'],
                           pred_len=self.args['pred_len'],
                           features=self.args['features'],
                           val_split=self.args['val_split'],
                           test_split=self.args['test_split'],
                           target=self.args['target'],
                           cluster=self.args['cluster'],
                           scale=True,
                           flag=flag)
        loader = DataLoader(dataset=data,
                            batch_size=self.args['batch_size'],
                            shuffle=shuffle_flag,
                            drop_last=True)
        return data, loader

    def _build_model(self):
        model = LSTM
        return model(input_size=self.train_data.x.shape[-1],
                     output_size=self.train_data.y.shape[-1],
                     hidden_size=self.args['hidden_size'],
                     num_layers=self.args['num_layers'],
                     batch_size=self.args['batch_size'])

    def train(self):
        self.train_data, self.train_loader = self._get_data(flag='train')
        self.val_data, self.val_loader = self._get_data(flag='val')
        self.test_data, self.test_loader = self._get_data(flag='test')
        self.model = self._build_model()
        model_optim = self._select_optimizer()
        criterion = self._select_criterion()
        train_steps = len(self.train_loader)
        early_stopping = EarlyStopping(patience=self.args['patience'],
                                       verbose=True)
        self.path = os.path.join(os.environ['RUNS_PATH'],
                                 self.args['timestamp'],
                                 f'cluster_{self.args["cluster"]}')
        os.makedirs(self.path, exist_ok=True)
        for epoch in range(self.args['epochs']):
            print('epoch: {}'.format(epoch + 1))
            train_losses = []
            self.model.train()
            epoch_time = datetime.now()
            self.writer = SummaryWriter(log_dir=os.path.join(
                self.path, 'tensorboards', f'epoc_{epoch+1}'))
            for i, (batch_x, batch_y) in enumerate(self.train_loader):
                batch_x = batch_x.float()
                batch_y = batch_y.float()
                model_optim.zero_grad()
                pred = self.model(batch_x)
                pred = pred[:, -self.args['pred_len']:, :]
                loss = torch.sqrt(criterion(pred, batch_y))
                self.writer.add_scalar('loss train/iter', loss, i)
                train_losses.append(loss.item())
                if i % self.args['log_interval'] == 0:
                    print('\titer: {0:>5d}/{1:>5d} | loss: {2:.3f}'.format(
                        i, train_steps, loss.item()))
                loss.backward()
                model_optim.step()
            train_loss = np.mean(train_losses)
            val_loss = self.evaluate(self.val_loader, criterion)
            test_loss = self.evaluate(self.test_loader, criterion)
            print('epoch {0} time: {1} s'.format(epoch + 1,
                                                 datetime.now() - epoch_time))
            print(
                'train loss: {0:.3f} | val loss: {1:.3f} | test loss: {2:.3f}'.
                format(train_loss, val_loss, test_loss))
            early_stopping(val_loss, self.model, self.path)
            self.writer.flush()
            if early_stopping.early_stop:
                print('early stopping!')
                break
            self.writer.close()
        best_model_path = os.path.join(self.path, 'checkpoint.pth')
        self.model = torch.load(best_model_path)
        return self.model

    def evaluate(self, loader, criterion):
        losses = []
        self.model.eval()
        with torch.no_grad():
            for i, (batch_x, batch_y) in enumerate(loader):
                batch_x = batch_x.float()
                batch_y = batch_y.float()
                pred = self.model(batch_x)
                pred = pred[:, -self.args['pred_len']:, :]
                loss = torch.sqrt(criterion(pred, batch_y))
                self.writer.add_scalar(f'loss {loader.dataset.flag}/iter',
                                       loss, i)
                losses.append(loss.item())
        loss = np.mean(losses)
        self.model.train()
        return loss

    def test(self):
        self.test_data, self.test_loader = self._get_data(flag='test')
        preds = []
        trues = []
        test_folder = os.path.join(self.path, 'test_results')
        os.makedirs(test_folder, exist_ok=True)
        self.model.eval()
        with torch.no_grad():
            for i, (batch_x, batch_y) in enumerate(self.test_loader):
                batch_x = batch_x.float()
                batch_y = batch_y.float()
                pred = self.model(batch_x)
                pred = torch.flatten(pred[:, -self.args['pred_len']:, -1])
                true = torch.flatten(batch_y.float())
                preds.append(pred.detach().cpu().numpy())
                trues.append(true.detach().cpu().numpy())
        preds = np.array(preds).flatten()
        trues = np.array(trues).flatten()
        visual(
            preds, trues,
            os.path.join(self.path,
                         f'test_cluster_{self.args["cluster"]}.pdf'))

    def predict(self):
        pred_data, pred_loader = self._get_data(flag='train')
        self.model.load_state_dict(torch.load(self.best_model_path))
        preds = []
        self.model.eval()
        with torch.no_grad():
            for i, (batch_x, batch_y) in enumerate(pred_loader):
                batch_x = batch_x.float().to(self.device)
                batch_y = batch_y.float()
                pred = self.model(batch_x)
                preds.append(pred)
        preds = np.array(preds)
        preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1])
        if (pred_data.scale):
            preds = pred_data.inverse_transform(preds)


def visual(true, preds, name):
    plt.figure()
    plt.plot(true, label='test ground truth', linewidth=2)
    if preds is not None:
        plt.plot(preds, label='test prediction', linewidth=2)
    plt.legend()
    plt.savefig(name, bbox_inches='tight')
    plt.close()

# %% [markdown]
# ## <a id='toc1_5_'></a>[Parameters](#toc0_)

# %%
task_params = dict(seq_len=14,
                   pred_len=1,
                   features=features,
                   target=target)
training_params = dict(val_split=0.2,
                       test_split=0.2,
                       batch_size=4,
                       patience=20,
                       epochs=500,
                       learning_rate=0.01,
                       log_interval=10,
                       seed=SEED)
model_params = dict(hidden_size=10, num_layers=2)

# %% [markdown]
# ## <a id='toc1_6_'></a>[Model](#toc0_)

# %%
exp = Experiment(
    {
        **task_params,
        **training_params,
        **model_params,
        'cluster': 0,
        'timestamp': '',
    }, )
exp.train_data, exp.train_loader = exp._get_data(flag='train')
exp._build_model()
# Out:
# X does not have valid feature names, but StandardScaler was fitted with feature names
# LSTM(
#   (lstm): LSTM(8, 10, num_layers=2, batch_first=True)
#   (linear): Linear(in_features=10, out_features=1, bias=True)
# )

# %% [markdown]
# ## <a id='toc1_7_'></a>[Training](#toc0_)

# %%
timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
for f in os.listdir(os.environ['PROCESSED_DATA_PATH']):
    if f.endswith('.csv'):
        exp = Experiment({
            **task_params,
            **training_params,
            **model_params, 'cluster':
            f.rstrip('.csv').lstrip('processed_'),
            'timestamp':
            timestamp
        })
        exp.train()
        exp.test()
# Out:
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# epoch: 1
# 	iter:     0/   34 | loss: 1.522
# 	iter:    10/   34 | loss: 0.700
# 	iter:    20/   34 | loss: 0.651
# 	iter:    30/   34 | loss: 0.132
# epoch 1 time: 0:00:00.280167 s
# train loss: 0.696 | val loss: 0.336 | test loss: 1.311
# validation loss decreased (inf --> 0.336)
# saving model
# epoch: 2
# 	iter:     0/   34 | loss: 0.241
# 	iter:    10/   34 | loss: 0.182
# 	iter:    20/   34 | loss: 0.499
# 	iter:    30/   34 | loss: 0.748
# epoch 2 time: 0:00:00.291251 s
# train loss: 0.211 | val loss: 0.343 | test loss: 1.157
# EarlyStopping counter: 1 out of 20
# epoch: 3
# 	iter:     0/   34 | loss: 0.082
# 	iter:    10/   34 | loss: 0.175
# 	iter:    20/   34 | loss: 0.149
# 	iter:    30/   34 | loss: 0.027
# epoch 3 time: 0:00:00.286351 s
# train loss: 0.198 | val loss: 0.309 | test loss: 0.853
# validation loss decreased (0.336 --> 0.309)
# saving model
# epoch: 4
# 	iter:     0/   34 | loss: 0.108
# 	iter:    10/   34 | loss: 0.475
# 	iter:    20/   34 | loss: 0.204
# 	iter:    30/   34 | loss: 0.061
# epoch 4 time: 0:00:00.280790 s
# train loss: 0.178 | val loss: 0.321 | test loss: 0.946
# EarlyStopping counter: 1 out of 20
# epoch: 5
# 	iter:     0/   34 | loss: 0.145
# 	iter:    10/   34 | loss: 0.076
# 	iter:    20/   34 | loss: 0.048
# 	iter:    30/   34 | loss: 0.286
# epoch 5 time: 0:00:00.373314 s
# train loss: 0.189 | val loss: 0.358 | test loss: 1.010
# EarlyStopping counter: 2 out of 20
# epoch: 6
# 	iter:     0/   34 | loss: 0.190
# 	iter:    10/   34 | loss: 0.058
# 	iter:    20/   34 | loss: 0.122
# 	iter:    30/   34 | loss: 0.067
# epoch 6 time: 0:00:00.267898 s
# train loss: 0.179 | val loss: 0.326 | test loss: 1.073
# EarlyStopping counter: 3 out of 20
# epoch: 7
# 	iter:     0/   34 | loss: 0.032
# 	iter:    10/   34 | loss: 0.013
# 	iter:    20/   34 | loss: 0.099
# 	iter:    30/   34 | loss: 0.047
# epoch 7 time: 0:00:00.238232 s
# train loss: 0.186 | val loss: 0.506 | test loss: 1.009
# EarlyStopping counter: 4 out of 20
# epoch: 8
# 	iter:     0/   34 | loss: 0.502
# 	iter:    10/   34 | loss: 0.054
# 	iter:    20/   34 | loss: 0.056
# 	iter:    30/   34 | loss: 0.051
# epoch 8 time: 0:00:00.249358 s
# train loss: 0.165 | val loss: 0.352 | test loss: 0.905
# EarlyStopping counter: 5 out of 20
# epoch: 9
# 	iter:     0/   34 | loss: 0.058
# 	iter:    10/   34 | loss: 0.450
# 	iter:    20/   34 | loss: 0.126
# 	iter:    30/   34 | loss: 0.469
# epoch 9 time: 0:00:00.246842 s
# train loss: 0.177 | val loss: 0.320 | test loss: 1.204
# EarlyStopping counter: 6 out of 20
# epoch: 10
# 	iter:     0/   34 | loss: 0.066
# 	iter:    10/   34 | loss: 0.081
# 	iter:    20/   34 | loss: 0.034
# 	iter:    30/   34 | loss: 0.416
# epoch 10 time: 0:00:00.240034 s
# train loss: 0.158 | val loss: 0.311 | test loss: 1.138
# EarlyStopping counter: 7 out of 20
# epoch: 11
# 	iter:     0/   34 | loss: 0.022
# 	iter:    10/   34 | loss: 0.120
# 	iter:    20/   34 | loss: 0.030
# 	iter:    30/   34 | loss: 0.035
# epoch 11 time: 0:00:00.240523 s
# train loss: 0.166 | val loss: 0.391 | test loss: 1.244
# EarlyStopping counter: 8 out of 20
# epoch: 12
# 	iter:     0/   34 | loss: 0.093
# 	iter:    10/   34 | loss: 0.103
# 	iter:    20/   34 | loss: 0.086
# 	iter:    30/   34 | loss: 0.387
# epoch 12 time: 0:00:00.271695 s
# train loss: 0.150 | val loss: 0.310 | test loss: 0.910
# EarlyStopping counter: 9 out of 20
# epoch: 13
# 	iter:     0/   34 | loss: 0.223
# 	iter:    10/   34 | loss: 0.420
# 	iter:    20/   34 | loss: 0.030
# 	iter:    30/   34 | loss: 0.343
# epoch 13 time: 0:00:00.265297 s
# train loss: 0.144 | val loss: 0.364 | test loss: 1.131
# EarlyStopping counter: 10 out of 20
# epoch: 14
# 	iter:     0/   34 | loss: 0.079
# 	iter:    10/   34 | loss: 0.368
# 	iter:    20/   34 | loss: 0.556
# 	iter:    30/   34 | loss: 0.032
# epoch 14 time: 0:00:00.250539 s
# train loss: 0.155 | val loss: 0.267 | test loss: 0.918
# validation loss decreased (0.309 --> 0.267)
# saving model
# epoch: 15
# 	iter:     0/   34 | loss: 0.023
# 	iter:    10/   34 | loss: 0.025
# 	iter:    20/   34 | loss: 0.036
# 	iter:    30/   34 | loss: 0.064
# epoch 15 time: 0:00:00.286768 s
# train loss: 0.136 | val loss: 0.338 | test loss: 1.104
# EarlyStopping counter: 1 out of 20
# epoch: 16
# 	iter:     0/   34 | loss: 0.061
# 	iter:    10/   34 | loss: 0.358
# 	iter:    20/   34 | loss: 0.300
# 	iter:    30/   34 | loss: 0.275
# epoch 16 time: 0:00:00.262032 s
# train loss: 0.164 | val loss: 0.368 | test loss: 1.270
# EarlyStopping counter: 2 out of 20
# epoch: 17
# 	iter:     0/   34 | loss: 0.119
# 	iter:    10/   34 | loss: 0.407
# 	iter:    20/   34 | loss: 0.009
# 	iter:    30/   34 | loss: 0.022
# epoch 17 time: 0:00:00.252955 s
# train loss: 0.109 | val loss: 0.307 | test loss: 1.086
# EarlyStopping counter: 3 out of 20
# epoch: 18
# 	iter:     0/   34 | loss: 0.102
# 	iter:    10/   34 | loss: 0.055
# 	iter:    20/   34 | loss: 0.095
# 	iter:    30/   34 | loss: 0.081
# epoch 18 time: 0:00:00.247382 s
# train loss: 0.116 | val loss: 0.294 | test loss: 1.138
# EarlyStopping counter: 4 out of 20
# epoch: 19
# 	iter:     0/   34 | loss: 0.399
# 	iter:    10/   34 | loss: 0.080
# 	iter:    20/   34 | loss: 0.113
# 	iter:    30/   34 | loss: 0.124
# epoch 19 time: 0:00:00.257379 s
# train loss: 0.143 | val loss: 0.322 | test loss: 1.179
# EarlyStopping counter: 5 out of 20
# epoch: 20
# 	iter:     0/   34 | loss: 0.254
# 	iter:    10/   34 | loss: 0.030
# 	iter:    20/   34 | loss: 0.162
# 	iter:    30/   34 | loss: 0.032
# epoch 20 time: 0:00:00.236202 s
# train loss: 0.107 | val loss: 0.298 | test loss: 1.151
# EarlyStopping counter: 6 out of 20
# epoch: 21
# 	iter:     0/   34 | loss: 0.055
# 	iter:    10/   34 | loss: 0.019
# 	iter:    20/   34 | loss: 0.028
# 	iter:    30/   34 | loss: 0.015
# epoch 21 time: 0:00:00.275210 s
# train loss: 0.086 | val loss: 0.340 | test loss: 1.185
# EarlyStopping counter: 7 out of 20
# epoch: 22
# 	iter:     0/   34 | loss: 0.052
# 	iter:    10/   34 | loss: 0.166
# 	iter:    20/   34 | loss: 0.038
# 	iter:    30/   34 | loss: 0.017
# epoch 22 time: 0:00:00.236903 s
# train loss: 0.085 | val loss: 0.344 | test loss: 1.226
# EarlyStopping counter: 8 out of 20
# epoch: 23
# 	iter:     0/   34 | loss: 0.109
# 	iter:    10/   34 | loss: 0.042
# 	iter:    20/   34 | loss: 0.030
# 	iter:    30/   34 | loss: 0.039
# epoch 23 time: 0:00:00.245143 s
# train loss: 0.075 | val loss: 0.311 | test loss: 1.193
# EarlyStopping counter: 9 out of 20
# epoch: 24
# 	iter:     0/   34 | loss: 0.017
# 	iter:    10/   34 | loss: 0.028
# 	iter:    20/   34 | loss: 0.045
# 	iter:    30/   34 | loss: 0.044
# epoch 24 time: 0:00:00.241923 s
# train loss: 0.066 | val loss: 0.320 | test loss: 1.265
# EarlyStopping counter: 10 out of 20
# epoch: 25
# 	iter:     0/   34 | loss: 0.075
# 	iter:    10/   34 | loss: 0.180
# 	iter:    20/   34 | loss: 0.021
# 	iter:    30/   34 | loss: 0.040
# epoch 25 time: 0:00:00.263100 s
# train loss: 0.096 | val loss: 0.312 | test loss: 1.232
# EarlyStopping counter: 11 out of 20
# epoch: 26
# 	iter:     0/   34 | loss: 0.026
# 	iter:    10/   34 | loss: 0.019
# 	iter:    20/   34 | loss: 0.025
# 	iter:    30/   34 | loss: 0.076
# epoch 26 time: 0:00:00.243117 s
# train loss: 0.072 | val loss: 0.410 | test loss: 1.303
# EarlyStopping counter: 12 out of 20
# epoch: 27
# 	iter:     0/   34 | loss: 0.110
# 	iter:    10/   34 | loss: 0.140
# 	iter:    20/   34 | loss: 0.062
# 	iter:    30/   34 | loss: 0.089
# epoch 27 time: 0:00:00.247458 s
# train loss: 0.102 | val loss: 0.246 | test loss: 1.124
# validation loss decreased (0.267 --> 0.246)
# saving model
# epoch: 28
# 	iter:     0/   34 | loss: 0.067
# 	iter:    10/   34 | loss: 0.168
# 	iter:    20/   34 | loss: 0.133
# 	iter:    30/   34 | loss: 0.113
# epoch 28 time: 0:00:00.273767 s
# train loss: 0.103 | val loss: 0.279 | test loss: 1.107
# EarlyStopping counter: 1 out of 20
# epoch: 29
# 	iter:     0/   34 | loss: 0.043
# 	iter:    10/   34 | loss: 0.068
# 	iter:    20/   34 | loss: 0.087
# 	iter:    30/   34 | loss: 0.023
# epoch 29 time: 0:00:00.257511 s
# train loss: 0.074 | val loss: 0.288 | test loss: 1.190
# EarlyStopping counter: 2 out of 20
# epoch: 30
# 	iter:     0/   34 | loss: 0.026
# 	iter:    10/   34 | loss: 0.068
# 	iter:    20/   34 | loss: 0.054
# 	iter:    30/   34 | loss: 0.064
# epoch 30 time: 0:00:00.269139 s
# train loss: 0.068 | val loss: 0.418 | test loss: 1.311
# EarlyStopping counter: 3 out of 20
# epoch: 31
# 	iter:     0/   34 | loss: 0.085
# 	iter:    10/   34 | loss: 0.015
# 	iter:    20/   34 | loss: 0.037
# 	iter:    30/   34 | loss: 0.065
# epoch 31 time: 0:00:00.260424 s
# train loss: 0.086 | val loss: 0.486 | test loss: 1.115
# EarlyStopping counter: 4 out of 20
# epoch: 32
# 	iter:     0/   34 | loss: 0.039
# 	iter:    10/   34 | loss: 0.014
# 	iter:    20/   34 | loss: 0.048
# 	iter:    30/   34 | loss: 0.082
# epoch 32 time: 0:00:00.253223 s
# train loss: 0.074 | val loss: 0.133 | test loss: 1.182
# validation loss decreased (0.246 --> 0.133)
# saving model
# epoch: 33
# 	iter:     0/   34 | loss: 0.034
# 	iter:    10/   34 | loss: 0.021
# 	iter:    20/   34 | loss: 0.015
# 	iter:    30/   34 | loss: 0.049
# epoch 33 time: 0:00:00.260254 s
# train loss: 0.058 | val loss: 0.340 | test loss: 1.075
# EarlyStopping counter: 1 out of 20
# epoch: 34
# 	iter:     0/   34 | loss: 0.027
# 	iter:    10/   34 | loss: 0.010
# 	iter:    20/   34 | loss: 0.045
# 	iter:    30/   34 | loss: 0.121
# epoch 34 time: 0:00:00.247194 s
# train loss: 0.070 | val loss: 0.382 | test loss: 1.274
# EarlyStopping counter: 2 out of 20
# epoch: 35
# 	iter:     0/   34 | loss: 0.123
# 	iter:    10/   34 | loss: 0.018
# 	iter:    20/   34 | loss: 0.045
# 	iter:    30/   34 | loss: 0.073
# epoch 35 time: 0:00:00.242155 s
# train loss: 0.079 | val loss: 0.474 | test loss: 1.056
# EarlyStopping counter: 3 out of 20
# epoch: 36
# 	iter:     0/   34 | loss: 0.023
# 	iter:    10/   34 | loss: 0.054
# 	iter:    20/   34 | loss: 0.071
# 	iter:    30/   34 | loss: 0.015
# epoch 36 time: 0:00:00.243811 s
# train loss: 0.053 | val loss: 0.346 | test loss: 1.196
# EarlyStopping counter: 4 out of 20
# epoch: 37
# 	iter:     0/   34 | loss: 0.018
# 	iter:    10/   34 | loss: 0.053
# 	iter:    20/   34 | loss: 0.030
# 	iter:    30/   34 | loss: 0.220
# epoch 37 time: 0:00:00.241714 s
# train loss: 0.072 | val loss: 0.501 | test loss: 1.108
# EarlyStopping counter: 5 out of 20
# epoch: 38
# 	iter:     0/   34 | loss: 0.016
# 	iter:    10/   34 | loss: 0.019
# 	iter:    20/   34 | loss: 0.129
# 	iter:    30/   34 | loss: 0.039
# epoch 38 time: 0:00:00.244948 s
# train loss: 0.058 | val loss: 0.520 | test loss: 1.189
# EarlyStopping counter: 6 out of 20
# epoch: 39
# 	iter:     0/   34 | loss: 0.083
# 	iter:    10/   34 | loss: 0.035
# 	iter:    20/   34 | loss: 0.048
# 	iter:    30/   34 | loss: 0.028
# epoch 39 time: 0:00:00.236902 s
# train loss: 0.062 | val loss: 0.533 | test loss: 1.234
# EarlyStopping counter: 7 out of 20
# epoch: 40
# 	iter:     0/   34 | loss: 0.014
# 	iter:    10/   34 | loss: 0.041
# 	iter:    20/   34 | loss: 0.021
# 	iter:    30/   34 | loss: 0.032
# epoch 40 time: 0:00:00.234966 s
# train loss: 0.049 | val loss: 0.435 | test loss: 1.194
# EarlyStopping counter: 8 out of 20
# epoch: 41
# 	iter:     0/   34 | loss: 0.026
# 	iter:    10/   34 | loss: 0.021
# 	iter:    20/   34 | loss: 0.039
# 	iter:    30/   34 | loss: 0.028
# epoch 41 time: 0:00:00.238475 s
# train loss: 0.047 | val loss: 0.405 | test loss: 1.222
# EarlyStopping counter: 9 out of 20
# epoch: 42
# 	iter:     0/   34 | loss: 0.043
# 	iter:    10/   34 | loss: 0.025
# 	iter:    20/   34 | loss: 0.009
# 	iter:    30/   34 | loss: 0.027
# epoch 42 time: 0:00:00.251648 s
# train loss: 0.053 | val loss: 0.386 | test loss: 1.205
# EarlyStopping counter: 10 out of 20
# epoch: 43
# 	iter:     0/   34 | loss: 0.023
# 	iter:    10/   34 | loss: 0.070
# 	iter:    20/   34 | loss: 0.142
# 	iter:    30/   34 | loss: 0.024
# epoch 43 time: 0:00:00.236804 s
# train loss: 0.048 | val loss: 0.345 | test loss: 1.220
# EarlyStopping counter: 11 out of 20
# epoch: 44
# 	iter:     0/   34 | loss: 0.085
# 	iter:    10/   34 | loss: 0.026
# 	iter:    20/   34 | loss: 0.079
# 	iter:    30/   34 | loss: 0.068
# epoch 44 time: 0:00:00.236283 s
# train loss: 0.069 | val loss: 0.487 | test loss: 1.277
# EarlyStopping counter: 12 out of 20
# epoch: 45
# 	iter:     0/   34 | loss: 0.090
# 	iter:    10/   34 | loss: 0.035
# 	iter:    20/   34 | loss: 0.018
# 	iter:    30/   34 | loss: 0.162
# epoch 45 time: 0:00:00.280799 s
# train loss: 0.053 | val loss: 0.423 | test loss: 1.136
# EarlyStopping counter: 13 out of 20
# epoch: 46
# 	iter:     0/   34 | loss: 0.120
# 	iter:    10/   34 | loss: 0.062
# 	iter:    20/   34 | loss: 0.049
# 	iter:    30/   34 | loss: 0.007
# epoch 46 time: 0:00:00.240071 s
# train loss: 0.061 | val loss: 0.513 | test loss: 1.172
# EarlyStopping counter: 14 out of 20
# epoch: 47
# 	iter:     0/   34 | loss: 0.106
# 	iter:    10/   34 | loss: 0.026
# 	iter:    20/   34 | loss: 0.015
# 	iter:    30/   34 | loss: 0.015
# epoch 47 time: 0:00:00.239760 s
# train loss: 0.044 | val loss: 0.289 | test loss: 1.201
# EarlyStopping counter: 15 out of 20
# epoch: 48
# 	iter:     0/   34 | loss: 0.089
# 	iter:    10/   34 | loss: 0.058
# 	iter:    20/   34 | loss: 0.071
# 	iter:    30/   34 | loss: 0.083
# epoch 48 time: 0:00:00.241289 s
# train loss: 0.056 | val loss: 0.393 | test loss: 1.207
# EarlyStopping counter: 16 out of 20
# epoch: 49
# 	iter:     0/   34 | loss: 0.036
# 	iter:    10/   34 | loss: 0.031
# 	iter:    20/   34 | loss: 0.046
# 	iter:    30/   34 | loss: 0.189
# epoch 49 time: 0:00:00.231805 s
# train loss: 0.051 | val loss: 0.530 | test loss: 1.214
# EarlyStopping counter: 17 out of 20
# epoch: 50
# 	iter:     0/   34 | loss: 0.044
# 	iter:    10/   34 | loss: 0.099
# 	iter:    20/   34 | loss: 0.036
# 	iter:    30/   34 | loss: 0.020
# epoch 50 time: 0:00:00.284664 s
# train loss: 0.045 | val loss: 0.616 | test loss: 1.208
# EarlyStopping counter: 18 out of 20
# epoch: 51
# 	iter:     0/   34 | loss: 0.013
# 	iter:    10/   34 | loss: 0.025
# 	iter:    20/   34 | loss: 0.075
# 	iter:    30/   34 | loss: 0.004
# epoch 51 time: 0:00:00.286235 s
# train loss: 0.035 | val loss: 0.631 | test loss: 1.159
# EarlyStopping counter: 19 out of 20
# epoch: 52
# 	iter:     0/   34 | loss: 0.014
# 	iter:    10/   34 | loss: 0.016
# 	iter:    20/   34 | loss: 0.025
# 	iter:    30/   34 | loss: 0.160
# epoch 52 time: 0:00:00.232854 s
# train loss: 0.043 | val loss: 0.312 | test loss: 1.174
# EarlyStopping counter: 20 out of 20
# early stopping!
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# epoch: 1
# 	iter:     0/   34 | loss: 1.470
# 	iter:    10/   34 | loss: 0.637
# 	iter:    20/   34 | loss: 0.608
# 	iter:    30/   34 | loss: 0.134
# epoch 1 time: 0:00:00.316909 s
# train loss: 0.690 | val loss: 1.150 | test loss: 0.677
# validation loss decreased (inf --> 1.150)
# saving model
# epoch: 2
# 	iter:     0/   34 | loss: 0.261
# 	iter:    10/   34 | loss: 0.211
# 	iter:    20/   34 | loss: 0.228
# 	iter:    30/   34 | loss: 0.525
# epoch 2 time: 0:00:00.283294 s
# train loss: 0.230 | val loss: 0.663 | test loss: 0.839
# validation loss decreased (1.150 --> 0.663)
# saving model
# epoch: 3
# 	iter:     0/   34 | loss: 0.094
# 	iter:    10/   34 | loss: 0.150
# 	iter:    20/   34 | loss: 0.045
# 	iter:    30/   34 | loss: 0.057
# epoch 3 time: 0:00:00.250146 s
# train loss: 0.191 | val loss: 0.679 | test loss: 0.596
# EarlyStopping counter: 1 out of 20
# epoch: 4
# 	iter:     0/   34 | loss: 0.133
# 	iter:    10/   34 | loss: 0.568
# 	iter:    20/   34 | loss: 0.078
# 	iter:    30/   34 | loss: 0.042
# epoch 4 time: 0:00:00.266308 s
# train loss: 0.217 | val loss: 0.899 | test loss: 0.625
# EarlyStopping counter: 2 out of 20
# epoch: 5
# 	iter:     0/   34 | loss: 0.180
# 	iter:    10/   34 | loss: 0.085
# 	iter:    20/   34 | loss: 0.070
# 	iter:    30/   34 | loss: 0.129
# epoch 5 time: 0:00:00.263664 s
# train loss: 0.188 | val loss: 0.854 | test loss: 0.756
# EarlyStopping counter: 3 out of 20
# epoch: 6
# 	iter:     0/   34 | loss: 0.284
# 	iter:    10/   34 | loss: 0.072
# 	iter:    20/   34 | loss: 0.110
# 	iter:    30/   34 | loss: 0.108
# epoch 6 time: 0:00:00.249938 s
# train loss: 0.212 | val loss: 1.005 | test loss: 0.938
# EarlyStopping counter: 4 out of 20
# epoch: 7
# 	iter:     0/   34 | loss: 0.117
# 	iter:    10/   34 | loss: 0.078
# 	iter:    20/   34 | loss: 0.085
# 	iter:    30/   34 | loss: 0.039
# epoch 7 time: 0:00:00.235473 s
# train loss: 0.207 | val loss: 0.905 | test loss: 0.718
# EarlyStopping counter: 5 out of 20
# epoch: 8
# 	iter:     0/   34 | loss: 0.514
# 	iter:    10/   34 | loss: 0.145
# 	iter:    20/   34 | loss: 0.075
# 	iter:    30/   34 | loss: 0.179
# epoch 8 time: 0:00:00.237027 s
# train loss: 0.201 | val loss: 0.859 | test loss: 0.493
# EarlyStopping counter: 6 out of 20
# epoch: 9
# 	iter:     0/   34 | loss: 0.102
# 	iter:    10/   34 | loss: 0.528
# 	iter:    20/   34 | loss: 0.028
# 	iter:    30/   34 | loss: 0.477
# epoch 9 time: 0:00:00.232898 s
# train loss: 0.180 | val loss: 0.748 | test loss: 0.628
# EarlyStopping counter: 7 out of 20
# epoch: 10
# 	iter:     0/   34 | loss: 0.301
# 	iter:    10/   34 | loss: 0.237
# 	iter:    20/   34 | loss: 0.135
# 	iter:    30/   34 | loss: 0.403
# epoch 10 time: 0:00:00.238266 s
# train loss: 0.180 | val loss: 0.565 | test loss: 0.505
# validation loss decreased (0.663 --> 0.565)
# saving model
# epoch: 11
# 	iter:     0/   34 | loss: 0.066
# 	iter:    10/   34 | loss: 0.302
# 	iter:    20/   34 | loss: 0.143
# 	iter:    30/   34 | loss: 0.133
# epoch 11 time: 0:00:00.241300 s
# train loss: 0.226 | val loss: 1.038 | test loss: 0.831
# EarlyStopping counter: 1 out of 20
# epoch: 12
# 	iter:     0/   34 | loss: 0.186
# 	iter:    10/   34 | loss: 0.149
# 	iter:    20/   34 | loss: 0.063
# 	iter:    30/   34 | loss: 0.466
# epoch 12 time: 0:00:00.260454 s
# train loss: 0.189 | val loss: 1.010 | test loss: 0.598
# EarlyStopping counter: 2 out of 20
# epoch: 13
# 	iter:     0/   34 | loss: 0.166
# 	iter:    10/   34 | loss: 0.466
# 	iter:    20/   34 | loss: 0.053
# 	iter:    30/   34 | loss: 0.476
# epoch 13 time: 0:00:00.236739 s
# train loss: 0.166 | val loss: 0.990 | test loss: 0.644
# EarlyStopping counter: 3 out of 20
# epoch: 14
# 	iter:     0/   34 | loss: 0.139
# 	iter:    10/   34 | loss: 0.466
# 	iter:    20/   34 | loss: 0.543
# 	iter:    30/   34 | loss: 0.047
# epoch 14 time: 0:00:00.243670 s
# train loss: 0.163 | val loss: 0.928 | test loss: 0.592
# EarlyStopping counter: 4 out of 20
# epoch: 15
# 	iter:     0/   34 | loss: 0.103
# 	iter:    10/   34 | loss: 0.037
# 	iter:    20/   34 | loss: 0.052
# 	iter:    30/   34 | loss: 0.036
# epoch 15 time: 0:00:00.267379 s
# train loss: 0.160 | val loss: 1.060 | test loss: 0.578
# EarlyStopping counter: 5 out of 20
# epoch: 16
# 	iter:     0/   34 | loss: 0.100
# 	iter:    10/   34 | loss: 0.219
# 	iter:    20/   34 | loss: 0.458
# 	iter:    30/   34 | loss: 0.463
# epoch 16 time: 0:00:00.258721 s
# train loss: 0.182 | val loss: 0.912 | test loss: 0.720
# EarlyStopping counter: 6 out of 20
# epoch: 17
# 	iter:     0/   34 | loss: 0.027
# 	iter:    10/   34 | loss: 0.460
# 	iter:    20/   34 | loss: 0.090
# 	iter:    30/   34 | loss: 0.042
# epoch 17 time: 0:00:00.223812 s
# train loss: 0.152 | val loss: 0.938 | test loss: 0.569
# EarlyStopping counter: 7 out of 20
# epoch: 18
# 	iter:     0/   34 | loss: 0.036
# 	iter:    10/   34 | loss: 0.047
# 	iter:    20/   34 | loss: 0.088
# 	iter:    30/   34 | loss: 0.113
# epoch 18 time: 0:00:00.278003 s
# train loss: 0.176 | val loss: 0.943 | test loss: 0.675
# EarlyStopping counter: 8 out of 20
# epoch: 19
# 	iter:     0/   34 | loss: 0.069
# 	iter:    10/   34 | loss: 0.012
# 	iter:    20/   34 | loss: 0.166
# 	iter:    30/   34 | loss: 0.093
# epoch 19 time: 0:00:00.246886 s
# train loss: 0.142 | val loss: 0.864 | test loss: 0.595
# EarlyStopping counter: 9 out of 20
# epoch: 20
# 	iter:     0/   34 | loss: 0.281
# 	iter:    10/   34 | loss: 0.061
# 	iter:    20/   34 | loss: 0.288
# 	iter:    30/   34 | loss: 0.122
# epoch 20 time: 0:00:00.240194 s
# train loss: 0.135 | val loss: 0.947 | test loss: 0.852
# EarlyStopping counter: 10 out of 20
# epoch: 21
# 	iter:     0/   34 | loss: 0.192
# 	iter:    10/   34 | loss: 0.156
# 	iter:    20/   34 | loss: 0.102
# 	iter:    30/   34 | loss: 0.068
# epoch 21 time: 0:00:00.243608 s
# train loss: 0.150 | val loss: 0.900 | test loss: 0.665
# EarlyStopping counter: 11 out of 20
# epoch: 22
# 	iter:     0/   34 | loss: 0.088
# 	iter:    10/   34 | loss: 0.175
# 	iter:    20/   34 | loss: 0.020
# 	iter:    30/   34 | loss: 0.187
# epoch 22 time: 0:00:00.257263 s
# train loss: 0.098 | val loss: 0.811 | test loss: 0.677
# EarlyStopping counter: 12 out of 20
# epoch: 23
# 	iter:     0/   34 | loss: 0.090
# 	iter:    10/   34 | loss: 0.033
# 	iter:    20/   34 | loss: 0.020
# 	iter:    30/   34 | loss: 0.075
# epoch 23 time: 0:00:00.240177 s
# train loss: 0.120 | val loss: 0.942 | test loss: 0.641
# EarlyStopping counter: 13 out of 20
# epoch: 24
# 	iter:     0/   34 | loss: 0.048
# 	iter:    10/   34 | loss: 0.065
# 	iter:    20/   34 | loss: 0.023
# 	iter:    30/   34 | loss: 0.017
# epoch 24 time: 0:00:00.236727 s
# train loss: 0.106 | val loss: 0.865 | test loss: 0.630
# EarlyStopping counter: 14 out of 20
# epoch: 25
# 	iter:     0/   34 | loss: 0.071
# 	iter:    10/   34 | loss: 0.230
# 	iter:    20/   34 | loss: 0.044
# 	iter:    30/   34 | loss: 0.151
# epoch 25 time: 0:00:00.232638 s
# train loss: 0.095 | val loss: 0.849 | test loss: 0.709
# EarlyStopping counter: 15 out of 20
# epoch: 26
# 	iter:     0/   34 | loss: 0.104
# 	iter:    10/   34 | loss: 0.012
# 	iter:    20/   34 | loss: 0.007
# 	iter:    30/   34 | loss: 0.082
# epoch 26 time: 0:00:00.235272 s
# train loss: 0.099 | val loss: 0.847 | test loss: 0.730
# EarlyStopping counter: 16 out of 20
# epoch: 27
# 	iter:     0/   34 | loss: 0.113
# 	iter:    10/   34 | loss: 0.094
# 	iter:    20/   34 | loss: 0.005
# 	iter:    30/   34 | loss: 0.051
# epoch 27 time: 0:00:00.252966 s
# train loss: 0.106 | val loss: 0.935 | test loss: 0.626
# EarlyStopping counter: 17 out of 20
# epoch: 28
# 	iter:     0/   34 | loss: 0.072
# 	iter:    10/   34 | loss: 0.149
# 	iter:    20/   34 | loss: 0.050
# 	iter:    30/   34 | loss: 0.081
# epoch 28 time: 0:00:00.305573 s
# train loss: 0.104 | val loss: 0.811 | test loss: 0.620
# EarlyStopping counter: 18 out of 20
# epoch: 29
# 	iter:     0/   34 | loss: 0.050
# 	iter:    10/   34 | loss: 0.107
# 	iter:    20/   34 | loss: 0.058
# 	iter:    30/   34 | loss: 0.111
# epoch 29 time: 0:00:00.255210 s
# train loss: 0.094 | val loss: 0.941 | test loss: 0.574
# EarlyStopping counter: 19 out of 20
# epoch: 30
# 	iter:     0/   34 | loss: 0.053
# 	iter:    10/   34 | loss: 0.076
# 	iter:    20/   34 | loss: 0.047
# 	iter:    30/   34 | loss: 0.035
# epoch 30 time: 0:00:00.262252 s
# train loss: 0.084 | val loss: 0.922 | test loss: 0.703
# EarlyStopping counter: 20 out of 20
# early stopping!
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# epoch: 1
# 	iter:     0/   34 | loss: 1.505
# 	iter:    10/   34 | loss: 0.628
# 	iter:    20/   34 | loss: 0.533
# 	iter:    30/   34 | loss: 0.200
# epoch 1 time: 0:00:00.394119 s
# train loss: 0.619 | val loss: 0.518 | test loss: 0.786
# validation loss decreased (inf --> 0.518)
# saving model
# epoch: 2
# 	iter:     0/   34 | loss: 0.236
# 	iter:    10/   34 | loss: 0.176
# 	iter:    20/   34 | loss: 0.097
# 	iter:    30/   34 | loss: 0.634
# epoch 2 time: 0:00:00.418653 s
# train loss: 0.200 | val loss: 0.296 | test loss: 0.624
# validation loss decreased (0.518 --> 0.296)
# saving model
# epoch: 3
# 	iter:     0/   34 | loss: 0.113
# 	iter:    10/   34 | loss: 0.093
# 	iter:    20/   34 | loss: 0.040
# 	iter:    30/   34 | loss: 0.087
# epoch 3 time: 0:00:00.347656 s
# train loss: 0.210 | val loss: 1.060 | test loss: 0.509
# EarlyStopping counter: 1 out of 20
# epoch: 4
# 	iter:     0/   34 | loss: 0.271
# 	iter:    10/   34 | loss: 0.531
# 	iter:    20/   34 | loss: 0.086
# 	iter:    30/   34 | loss: 0.077
# epoch 4 time: 0:00:00.305423 s
# train loss: 0.207 | val loss: 0.365 | test loss: 0.703
# EarlyStopping counter: 2 out of 20
# epoch: 5
# 	iter:     0/   34 | loss: 0.181
# 	iter:    10/   34 | loss: 0.107
# 	iter:    20/   34 | loss: 0.062
# 	iter:    30/   34 | loss: 0.047
# epoch 5 time: 0:00:00.241376 s
# train loss: 0.159 | val loss: 0.379 | test loss: 0.764
# EarlyStopping counter: 3 out of 20
# epoch: 6
# 	iter:     0/   34 | loss: 0.131
# 	iter:    10/   34 | loss: 0.057
# 	iter:    20/   34 | loss: 0.035
# 	iter:    30/   34 | loss: 0.040
# epoch 6 time: 0:00:00.225674 s
# train loss: 0.176 | val loss: 0.725 | test loss: 0.668
# EarlyStopping counter: 4 out of 20
# epoch: 7
# 	iter:     0/   34 | loss: 0.059
# 	iter:    10/   34 | loss: 0.033
# 	iter:    20/   34 | loss: 0.123
# 	iter:    30/   34 | loss: 0.090
# epoch 7 time: 0:00:00.215640 s
# train loss: 0.205 | val loss: 0.528 | test loss: 0.717
# EarlyStopping counter: 5 out of 20
# epoch: 8
# 	iter:     0/   34 | loss: 0.493
# 	iter:    10/   34 | loss: 0.209
# 	iter:    20/   34 | loss: 0.048
# 	iter:    30/   34 | loss: 0.011
# epoch 8 time: 0:00:00.230741 s
# train loss: 0.182 | val loss: 0.584 | test loss: 0.829
# EarlyStopping counter: 6 out of 20
# epoch: 9
# 	iter:     0/   34 | loss: 0.051
# 	iter:    10/   34 | loss: 0.490
# 	iter:    20/   34 | loss: 0.075
# 	iter:    30/   34 | loss: 0.453
# epoch 9 time: 0:00:00.271343 s
# train loss: 0.168 | val loss: 0.645 | test loss: 0.700
# EarlyStopping counter: 7 out of 20
# epoch: 10
# 	iter:     0/   34 | loss: 0.065
# 	iter:    10/   34 | loss: 0.405
# 	iter:    20/   34 | loss: 0.150
# 	iter:    30/   34 | loss: 0.458
# epoch 10 time: 0:00:00.254265 s
# train loss: 0.177 | val loss: 0.566 | test loss: 0.624
# EarlyStopping counter: 8 out of 20
# epoch: 11
# 	iter:     0/   34 | loss: 0.004
# 	iter:    10/   34 | loss: 0.133
# 	iter:    20/   34 | loss: 0.044
# 	iter:    30/   34 | loss: 0.039
# epoch 11 time: 0:00:00.225864 s
# train loss: 0.174 | val loss: 0.703 | test loss: 0.772
# EarlyStopping counter: 9 out of 20
# epoch: 12
# 	iter:     0/   34 | loss: 0.118
# 	iter:    10/   34 | loss: 0.074
# 	iter:    20/   34 | loss: 0.038
# 	iter:    30/   34 | loss: 0.452
# epoch 12 time: 0:00:00.273496 s
# train loss: 0.160 | val loss: 1.056 | test loss: 0.674
# EarlyStopping counter: 10 out of 20
# epoch: 13
# 	iter:     0/   34 | loss: 0.223
# 	iter:    10/   34 | loss: 0.413
# 	iter:    20/   34 | loss: 0.029
# 	iter:    30/   34 | loss: 0.448
# epoch 13 time: 0:00:00.234076 s
# train loss: 0.152 | val loss: 1.121 | test loss: 0.716
# EarlyStopping counter: 11 out of 20
# epoch: 14
# 	iter:     0/   34 | loss: 0.081
# 	iter:    10/   34 | loss: 0.437
# 	iter:    20/   34 | loss: 0.591
# 	iter:    30/   34 | loss: 0.060
# epoch 14 time: 0:00:00.242269 s
# train loss: 0.167 | val loss: 1.114 | test loss: 0.614
# EarlyStopping counter: 12 out of 20
# epoch: 15
# 	iter:     0/   34 | loss: 0.087
# 	iter:    10/   34 | loss: 0.032
# 	iter:    20/   34 | loss: 0.079
# 	iter:    30/   34 | loss: 0.090
# epoch 15 time: 0:00:00.219670 s
# train loss: 0.148 | val loss: 0.875 | test loss: 0.765
# EarlyStopping counter: 13 out of 20
# epoch: 16
# 	iter:     0/   34 | loss: 0.070
# 	iter:    10/   34 | loss: 0.298
# 	iter:    20/   34 | loss: 0.420
# 	iter:    30/   34 | loss: 0.404
# epoch 16 time: 0:00:00.224962 s
# train loss: 0.157 | val loss: 0.797 | test loss: 0.807
# EarlyStopping counter: 14 out of 20
# epoch: 17
# 	iter:     0/   34 | loss: 0.023
# 	iter:    10/   34 | loss: 0.477
# 	iter:    20/   34 | loss: 0.044
# 	iter:    30/   34 | loss: 0.026
# epoch 17 time: 0:00:00.272715 s
# train loss: 0.130 | val loss: 0.945 | test loss: 0.702
# EarlyStopping counter: 15 out of 20
# epoch: 18
# 	iter:     0/   34 | loss: 0.059
# 	iter:    10/   34 | loss: 0.018
# 	iter:    20/   34 | loss: 0.136
# 	iter:    30/   34 | loss: 0.047
# epoch 18 time: 0:00:00.387597 s
# train loss: 0.141 | val loss: 0.867 | test loss: 0.701
# EarlyStopping counter: 16 out of 20
# epoch: 19
# 	iter:     0/   34 | loss: 0.011
# 	iter:    10/   34 | loss: 0.021
# 	iter:    20/   34 | loss: 0.056
# 	iter:    30/   34 | loss: 0.071
# epoch 19 time: 0:00:00.301814 s
# train loss: 0.123 | val loss: 0.805 | test loss: 0.695
# EarlyStopping counter: 17 out of 20
# epoch: 20
# 	iter:     0/   34 | loss: 0.103
# 	iter:    10/   34 | loss: 0.045
# 	iter:    20/   34 | loss: 0.310
# 	iter:    30/   34 | loss: 0.037
# epoch 20 time: 0:00:00.294837 s
# train loss: 0.129 | val loss: 0.792 | test loss: 0.680
# EarlyStopping counter: 18 out of 20
# epoch: 21
# 	iter:     0/   34 | loss: 0.061
# 	iter:    10/   34 | loss: 0.027
# 	iter:    20/   34 | loss: 0.072
# 	iter:    30/   34 | loss: 0.017
# epoch 21 time: 0:00:00.306454 s
# train loss: 0.148 | val loss: 1.054 | test loss: 0.662
# EarlyStopping counter: 19 out of 20
# epoch: 22
# 	iter:     0/   34 | loss: 0.057
# 	iter:    10/   34 | loss: 0.116
# 	iter:    20/   34 | loss: 0.048
# 	iter:    30/   34 | loss: 0.052
# epoch 22 time: 0:00:00.252153 s
# train loss: 0.146 | val loss: 0.905 | test loss: 0.650
# EarlyStopping counter: 20 out of 20
# early stopping!
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# epoch: 1
# 	iter:     0/   34 | loss: 1.550
# 	iter:    10/   34 | loss: 0.611
# 	iter:    20/   34 | loss: 0.599
# 	iter:    30/   34 | loss: 0.145
# epoch 1 time: 0:00:00.232352 s
# train loss: 0.680 | val loss: 0.802 | test loss: 1.705
# validation loss decreased (inf --> 0.802)
# saving model
# epoch: 2
# 	iter:     0/   34 | loss: 0.178
# 	iter:    10/   34 | loss: 0.221
# 	iter:    20/   34 | loss: 0.067
# 	iter:    30/   34 | loss: 0.655
# epoch 2 time: 0:00:00.219687 s
# train loss: 0.223 | val loss: 0.789 | test loss: 1.487
# validation loss decreased (0.802 --> 0.789)
# saving model
# epoch: 3
# 	iter:     0/   34 | loss: 0.141
# 	iter:    10/   34 | loss: 0.285
# 	iter:    20/   34 | loss: 0.070
# 	iter:    30/   34 | loss: 0.028
# epoch 3 time: 0:00:00.245602 s
# train loss: 0.213 | val loss: 0.872 | test loss: 1.130
# EarlyStopping counter: 1 out of 20
# epoch: 4
# 	iter:     0/   34 | loss: 0.079
# 	iter:    10/   34 | loss: 0.502
# 	iter:    20/   34 | loss: 0.183
# 	iter:    30/   34 | loss: 0.047
# epoch 4 time: 0:00:00.218033 s
# train loss: 0.222 | val loss: 0.784 | test loss: 1.523
# validation loss decreased (0.789 --> 0.784)
# saving model
# epoch: 5
# 	iter:     0/   34 | loss: 0.156
# 	iter:    10/   34 | loss: 0.071
# 	iter:    20/   34 | loss: 0.115
# 	iter:    30/   34 | loss: 0.743
# epoch 5 time: 0:00:00.273438 s
# train loss: 0.205 | val loss: 0.756 | test loss: 1.070
# validation loss decreased (0.784 --> 0.756)
# saving model
# epoch: 6
# 	iter:     0/   34 | loss: 0.170
# 	iter:    10/   34 | loss: 0.129
# 	iter:    20/   34 | loss: 0.160
# 	iter:    30/   34 | loss: 0.176
# epoch 6 time: 0:00:00.241287 s
# train loss: 0.210 | val loss: 0.907 | test loss: 1.663
# EarlyStopping counter: 1 out of 20
# epoch: 7
# 	iter:     0/   34 | loss: 0.152
# 	iter:    10/   34 | loss: 0.134
# 	iter:    20/   34 | loss: 0.117
# 	iter:    30/   34 | loss: 0.060
# epoch 7 time: 0:00:00.227377 s
# train loss: 0.193 | val loss: 0.695 | test loss: 1.079
# validation loss decreased (0.756 --> 0.695)
# saving model
# epoch: 8
# 	iter:     0/   34 | loss: 0.447
# 	iter:    10/   34 | loss: 0.064
# 	iter:    20/   34 | loss: 0.044
# 	iter:    30/   34 | loss: 0.128
# epoch 8 time: 0:00:00.234024 s
# train loss: 0.160 | val loss: 0.629 | test loss: 1.084
# validation loss decreased (0.695 --> 0.629)
# saving model
# epoch: 9
# 	iter:     0/   34 | loss: 0.097
# 	iter:    10/   34 | loss: 0.301
# 	iter:    20/   34 | loss: 0.112
# 	iter:    30/   34 | loss: 0.296
# epoch 9 time: 0:00:00.222847 s
# train loss: 0.160 | val loss: 0.956 | test loss: 1.608
# EarlyStopping counter: 1 out of 20
# epoch: 10
# 	iter:     0/   34 | loss: 0.127
# 	iter:    10/   34 | loss: 0.200
# 	iter:    20/   34 | loss: 0.161
# 	iter:    30/   34 | loss: 0.138
# epoch 10 time: 0:00:00.228983 s
# train loss: 0.151 | val loss: 0.878 | test loss: 1.521
# EarlyStopping counter: 2 out of 20
# epoch: 11
# 	iter:     0/   34 | loss: 0.027
# 	iter:    10/   34 | loss: 0.070
# 	iter:    20/   34 | loss: 0.073
# 	iter:    30/   34 | loss: 0.049
# epoch 11 time: 0:00:00.225960 s
# train loss: 0.163 | val loss: 0.973 | test loss: 1.640
# EarlyStopping counter: 3 out of 20
# epoch: 12
# 	iter:     0/   34 | loss: 0.250
# 	iter:    10/   34 | loss: 0.063
# 	iter:    20/   34 | loss: 0.091
# 	iter:    30/   34 | loss: 0.077
# epoch 12 time: 0:00:00.223314 s
# train loss: 0.158 | val loss: 0.808 | test loss: 1.202
# EarlyStopping counter: 4 out of 20
# epoch: 13
# 	iter:     0/   34 | loss: 0.267
# 	iter:    10/   34 | loss: 0.130
# 	iter:    20/   34 | loss: 0.006
# 	iter:    30/   34 | loss: 0.168
# epoch 13 time: 0:00:00.225862 s
# train loss: 0.129 | val loss: 0.723 | test loss: 1.621
# EarlyStopping counter: 5 out of 20
# epoch: 14
# 	iter:     0/   34 | loss: 0.182
# 	iter:    10/   34 | loss: 0.004
# 	iter:    20/   34 | loss: 0.760
# 	iter:    30/   34 | loss: 0.056
# epoch 14 time: 0:00:00.222645 s
# train loss: 0.110 | val loss: 0.778 | test loss: 1.484
# EarlyStopping counter: 6 out of 20
# epoch: 15
# 	iter:     0/   34 | loss: 0.062
# 	iter:    10/   34 | loss: 0.062
# 	iter:    20/   34 | loss: 0.071
# 	iter:    30/   34 | loss: 0.101
# epoch 15 time: 0:00:00.215314 s
# train loss: 0.132 | val loss: 0.836 | test loss: 1.427
# EarlyStopping counter: 7 out of 20
# epoch: 16
# 	iter:     0/   34 | loss: 0.037
# 	iter:    10/   34 | loss: 0.283
# 	iter:    20/   34 | loss: 0.106
# 	iter:    30/   34 | loss: 0.162
# epoch 16 time: 0:00:00.226660 s
# train loss: 0.124 | val loss: 0.875 | test loss: 1.619
# EarlyStopping counter: 8 out of 20
# epoch: 17
# 	iter:     0/   34 | loss: 0.060
# 	iter:    10/   34 | loss: 0.090
# 	iter:    20/   34 | loss: 0.053
# 	iter:    30/   34 | loss: 0.137
# epoch 17 time: 0:00:00.215837 s
# train loss: 0.090 | val loss: 0.822 | test loss: 1.527
# EarlyStopping counter: 9 out of 20
# epoch: 18
# 	iter:     0/   34 | loss: 0.045
# 	iter:    10/   34 | loss: 0.088
# 	iter:    20/   34 | loss: 0.101
# 	iter:    30/   34 | loss: 0.039
# epoch 18 time: 0:00:00.286523 s
# train loss: 0.099 | val loss: 0.790 | test loss: 1.523
# EarlyStopping counter: 10 out of 20
# epoch: 19
# 	iter:     0/   34 | loss: 0.055
# 	iter:    10/   34 | loss: 0.028
# 	iter:    20/   34 | loss: 0.037
# 	iter:    30/   34 | loss: 0.067
# epoch 19 time: 0:00:00.229160 s
# train loss: 0.086 | val loss: 0.700 | test loss: 1.507
# EarlyStopping counter: 11 out of 20
# epoch: 20
# 	iter:     0/   34 | loss: 0.372
# 	iter:    10/   34 | loss: 0.046
# 	iter:    20/   34 | loss: 0.049
# 	iter:    30/   34 | loss: 0.023
# epoch 20 time: 0:00:00.222699 s
# train loss: 0.090 | val loss: 0.708 | test loss: 1.475
# EarlyStopping counter: 12 out of 20
# epoch: 21
# 	iter:     0/   34 | loss: 0.090
# 	iter:    10/   34 | loss: 0.074
# 	iter:    20/   34 | loss: 0.115
# 	iter:    30/   34 | loss: 0.043
# epoch 21 time: 0:00:00.290707 s
# train loss: 0.115 | val loss: 0.732 | test loss: 1.457
# EarlyStopping counter: 13 out of 20
# epoch: 22
# 	iter:     0/   34 | loss: 0.016
# 	iter:    10/   34 | loss: 0.009
# 	iter:    20/   34 | loss: 0.118
# 	iter:    30/   34 | loss: 0.161
# epoch 22 time: 0:00:00.217482 s
# train loss: 0.099 | val loss: 0.604 | test loss: 1.537
# validation loss decreased (0.629 --> 0.604)
# saving model
# epoch: 23
# 	iter:     0/   34 | loss: 0.060
# 	iter:    10/   34 | loss: 0.057
# 	iter:    20/   34 | loss: 0.025
# 	iter:    30/   34 | loss: 0.015
# epoch 23 time: 0:00:00.251317 s
# train loss: 0.089 | val loss: 0.755 | test loss: 1.571
# EarlyStopping counter: 1 out of 20
# epoch: 24
# 	iter:     0/   34 | loss: 0.061
# 	iter:    10/   34 | loss: 0.063
# 	iter:    20/   34 | loss: 0.031
# 	iter:    30/   34 | loss: 0.095
# epoch 24 time: 0:00:00.292266 s
# train loss: 0.068 | val loss: 0.672 | test loss: 1.613
# EarlyStopping counter: 2 out of 20
# epoch: 25
# 	iter:     0/   34 | loss: 0.003
# 	iter:    10/   34 | loss: 0.284
# 	iter:    20/   34 | loss: 0.024
# 	iter:    30/   34 | loss: 0.067
# epoch 25 time: 0:00:00.237253 s
# train loss: 0.079 | val loss: 0.764 | test loss: 1.606
# EarlyStopping counter: 3 out of 20
# epoch: 26
# 	iter:     0/   34 | loss: 0.050
# 	iter:    10/   34 | loss: 0.019
# 	iter:    20/   34 | loss: 0.049
# 	iter:    30/   34 | loss: 0.055
# epoch 26 time: 0:00:00.239209 s
# train loss: 0.090 | val loss: 0.751 | test loss: 1.586
# EarlyStopping counter: 4 out of 20
# epoch: 27
# 	iter:     0/   34 | loss: 0.095
# 	iter:    10/   34 | loss: 0.063
# 	iter:    20/   34 | loss: 0.010
# 	iter:    30/   34 | loss: 0.136
# epoch 27 time: 0:00:00.225299 s
# train loss: 0.105 | val loss: 0.658 | test loss: 1.530
# EarlyStopping counter: 5 out of 20
# epoch: 28
# 	iter:     0/   34 | loss: 0.035
# 	iter:    10/   34 | loss: 0.034
# 	iter:    20/   34 | loss: 0.057
# 	iter:    30/   34 | loss: 0.238
# epoch 28 time: 0:00:00.219165 s
# train loss: 0.084 | val loss: 0.692 | test loss: 1.630
# EarlyStopping counter: 6 out of 20
# epoch: 29
# 	iter:     0/   34 | loss: 0.045
# 	iter:    10/   34 | loss: 0.014
# 	iter:    20/   34 | loss: 0.057
# 	iter:    30/   34 | loss: 0.160
# epoch 29 time: 0:00:00.230544 s
# train loss: 0.081 | val loss: 0.666 | test loss: 1.570
# EarlyStopping counter: 7 out of 20
# epoch: 30
# 	iter:     0/   34 | loss: 0.029
# 	iter:    10/   34 | loss: 0.161
# 	iter:    20/   34 | loss: 0.040
# 	iter:    30/   34 | loss: 0.077
# epoch 30 time: 0:00:00.220742 s
# train loss: 0.089 | val loss: 0.772 | test loss: 1.558
# EarlyStopping counter: 8 out of 20
# epoch: 31
# 	iter:     0/   34 | loss: 0.014
# 	iter:    10/   34 | loss: 0.051
# 	iter:    20/   34 | loss: 0.170
# 	iter:    30/   34 | loss: 0.032
# epoch 31 time: 0:00:00.227303 s
# train loss: 0.104 | val loss: 0.667 | test loss: 1.680
# EarlyStopping counter: 9 out of 20
# epoch: 32
# 	iter:     0/   34 | loss: 0.097
# 	iter:    10/   34 | loss: 0.043
# 	iter:    20/   34 | loss: 0.023
# 	iter:    30/   34 | loss: 0.091
# epoch 32 time: 0:00:00.219935 s
# train loss: 0.083 | val loss: 0.629 | test loss: 1.579
# EarlyStopping counter: 10 out of 20
# epoch: 33
# 	iter:     0/   34 | loss: 0.017
# 	iter:    10/   34 | loss: 0.029
# 	iter:    20/   34 | loss: 0.028
# 	iter:    30/   34 | loss: 0.101
# epoch 33 time: 0:00:00.217718 s
# train loss: 0.081 | val loss: 0.617 | test loss: 1.376
# EarlyStopping counter: 11 out of 20
# epoch: 34
# 	iter:     0/   34 | loss: 0.072
# 	iter:    10/   34 | loss: 0.044
# 	iter:    20/   34 | loss: 0.057
# 	iter:    30/   34 | loss: 0.039
# epoch 34 time: 0:00:00.226824 s
# train loss: 0.086 | val loss: 0.638 | test loss: 1.642
# EarlyStopping counter: 12 out of 20
# epoch: 35
# 	iter:     0/   34 | loss: 0.124
# 	iter:    10/   34 | loss: 0.011
# 	iter:    20/   34 | loss: 0.065
# 	iter:    30/   34 | loss: 0.040
# epoch 35 time: 0:00:00.233719 s
# train loss: 0.063 | val loss: 0.532 | test loss: 1.592
# validation loss decreased (0.604 --> 0.532)
# saving model
# epoch: 36
# 	iter:     0/   34 | loss: 0.015
# 	iter:    10/   34 | loss: 0.051
# 	iter:    20/   34 | loss: 0.038
# 	iter:    30/   34 | loss: 0.034
# epoch 36 time: 0:00:00.218300 s
# train loss: 0.064 | val loss: 0.650 | test loss: 1.650
# EarlyStopping counter: 1 out of 20
# epoch: 37
# 	iter:     0/   34 | loss: 0.072
# 	iter:    10/   34 | loss: 0.041
# 	iter:    20/   34 | loss: 0.021
# 	iter:    30/   34 | loss: 0.168
# epoch 37 time: 0:00:00.213536 s
# train loss: 0.074 | val loss: 0.637 | test loss: 1.610
# EarlyStopping counter: 2 out of 20
# epoch: 38
# 	iter:     0/   34 | loss: 0.044
# 	iter:    10/   34 | loss: 0.084
# 	iter:    20/   34 | loss: 0.083
# 	iter:    30/   34 | loss: 0.059
# epoch 38 time: 0:00:00.215710 s
# train loss: 0.075 | val loss: 0.643 | test loss: 1.627
# EarlyStopping counter: 3 out of 20
# epoch: 39
# 	iter:     0/   34 | loss: 0.223
# 	iter:    10/   34 | loss: 0.015
# 	iter:    20/   34 | loss: 0.175
# 	iter:    30/   34 | loss: 0.097
# epoch 39 time: 0:00:00.228222 s
# train loss: 0.080 | val loss: 0.633 | test loss: 1.603
# EarlyStopping counter: 4 out of 20
# epoch: 40
# 	iter:     0/   34 | loss: 0.067
# 	iter:    10/   34 | loss: 0.025
# 	iter:    20/   34 | loss: 0.028
# 	iter:    30/   34 | loss: 0.062
# epoch 40 time: 0:00:00.221302 s
# train loss: 0.067 | val loss: 0.532 | test loss: 1.554
# validation loss decreased (0.532 --> 0.532)
# saving model
# epoch: 41
# 	iter:     0/   34 | loss: 0.075
# 	iter:    10/   34 | loss: 0.030
# 	iter:    20/   34 | loss: 0.107
# 	iter:    30/   34 | loss: 0.064
# epoch 41 time: 0:00:00.267761 s
# train loss: 0.075 | val loss: 0.564 | test loss: 1.679
# EarlyStopping counter: 1 out of 20
# epoch: 42
# 	iter:     0/   34 | loss: 0.108
# 	iter:    10/   34 | loss: 0.080
# 	iter:    20/   34 | loss: 0.028
# 	iter:    30/   34 | loss: 0.008
# epoch 42 time: 0:00:00.245275 s
# train loss: 0.078 | val loss: 0.679 | test loss: 1.569
# EarlyStopping counter: 2 out of 20
# epoch: 43
# 	iter:     0/   34 | loss: 0.071
# 	iter:    10/   34 | loss: 0.057
# 	iter:    20/   34 | loss: 0.392
# 	iter:    30/   34 | loss: 0.022
# epoch 43 time: 0:00:00.224539 s
# train loss: 0.062 | val loss: 0.653 | test loss: 1.602
# EarlyStopping counter: 3 out of 20
# epoch: 44
# 	iter:     0/   34 | loss: 0.019
# 	iter:    10/   34 | loss: 0.002
# 	iter:    20/   34 | loss: 0.035
# 	iter:    30/   34 | loss: 0.058
# epoch 44 time: 0:00:00.234240 s
# train loss: 0.054 | val loss: 0.672 | test loss: 1.578
# EarlyStopping counter: 4 out of 20
# epoch: 45
# 	iter:     0/   34 | loss: 0.025
# 	iter:    10/   34 | loss: 0.006
# 	iter:    20/   34 | loss: 0.034
# 	iter:    30/   34 | loss: 0.212
# epoch 45 time: 0:00:00.252209 s
# train loss: 0.054 | val loss: 0.573 | test loss: 1.548
# EarlyStopping counter: 5 out of 20
# epoch: 46
# 	iter:     0/   34 | loss: 0.028
# 	iter:    10/   34 | loss: 0.048
# 	iter:    20/   34 | loss: 0.072
# 	iter:    30/   34 | loss: 0.019
# epoch 46 time: 0:00:00.262433 s
# train loss: 0.073 | val loss: 0.804 | test loss: 1.564
# EarlyStopping counter: 6 out of 20
# epoch: 47
# 	iter:     0/   34 | loss: 0.051
# 	iter:    10/   34 | loss: 0.026
# 	iter:    20/   34 | loss: 0.036
# 	iter:    30/   34 | loss: 0.041
# epoch 47 time: 0:00:00.271564 s
# train loss: 0.057 | val loss: 0.564 | test loss: 1.466
# EarlyStopping counter: 7 out of 20
# epoch: 48
# 	iter:     0/   34 | loss: 0.041
# 	iter:    10/   34 | loss: 0.033
# 	iter:    20/   34 | loss: 0.008
# 	iter:    30/   34 | loss: 0.020
# epoch 48 time: 0:00:00.231848 s
# train loss: 0.058 | val loss: 0.897 | test loss: 1.594
# EarlyStopping counter: 8 out of 20
# epoch: 49
# 	iter:     0/   34 | loss: 0.050
# 	iter:    10/   34 | loss: 0.084
# 	iter:    20/   34 | loss: 0.010
# 	iter:    30/   34 | loss: 0.068
# epoch 49 time: 0:00:00.231770 s
# train loss: 0.079 | val loss: 0.915 | test loss: 1.596
# EarlyStopping counter: 9 out of 20
# epoch: 50
# 	iter:     0/   34 | loss: 0.057
# 	iter:    10/   34 | loss: 0.053
# 	iter:    20/   34 | loss: 0.067
# 	iter:    30/   34 | loss: 0.058
# epoch 50 time: 0:00:00.226648 s
# train loss: 0.065 | val loss: 0.764 | test loss: 1.555
# EarlyStopping counter: 10 out of 20
# epoch: 51
# 	iter:     0/   34 | loss: 0.060
# 	iter:    10/   34 | loss: 0.038
# 	iter:    20/   34 | loss: 0.037
# 	iter:    30/   34 | loss: 0.019
# epoch 51 time: 0:00:00.218174 s
# train loss: 0.050 | val loss: 0.796 | test loss: 1.587
# EarlyStopping counter: 11 out of 20
# epoch: 52
# 	iter:     0/   34 | loss: 0.003
# 	iter:    10/   34 | loss: 0.020
# 	iter:    20/   34 | loss: 0.039
# 	iter:    30/   34 | loss: 0.237
# epoch 52 time: 0:00:00.221278 s
# train loss: 0.058 | val loss: 0.749 | test loss: 1.615
# EarlyStopping counter: 12 out of 20
# epoch: 53
# 	iter:     0/   34 | loss: 0.022
# 	iter:    10/   34 | loss: 0.002
# 	iter:    20/   34 | loss: 0.022
# 	iter:    30/   34 | loss: 0.015
# epoch 53 time: 0:00:00.223670 s
# train loss: 0.066 | val loss: 0.809 | test loss: 1.618
# EarlyStopping counter: 13 out of 20
# epoch: 54
# 	iter:     0/   34 | loss: 0.026
# 	iter:    10/   34 | loss: 0.181
# 	iter:    20/   34 | loss: 0.161
# 	iter:    30/   34 | loss: 0.023
# epoch 54 time: 0:00:00.400802 s
# train loss: 0.055 | val loss: 0.765 | test loss: 1.680
# EarlyStopping counter: 14 out of 20
# epoch: 55
# 	iter:     0/   34 | loss: 0.046
# 	iter:    10/   34 | loss: 0.032
# 	iter:    20/   34 | loss: 0.013
# 	iter:    30/   34 | loss: 0.025
# epoch 55 time: 0:00:00.269878 s
# train loss: 0.066 | val loss: 0.662 | test loss: 1.499
# EarlyStopping counter: 15 out of 20
# epoch: 56
# 	iter:     0/   34 | loss: 0.033
# 	iter:    10/   34 | loss: 0.005
# 	iter:    20/   34 | loss: 0.013
# 	iter:    30/   34 | loss: 0.125
# epoch 56 time: 0:00:00.296072 s
# train loss: 0.049 | val loss: 0.705 | test loss: 1.542
# EarlyStopping counter: 16 out of 20
# epoch: 57
# 	iter:     0/   34 | loss: 0.017
# 	iter:    10/   34 | loss: 0.008
# 	iter:    20/   34 | loss: 0.038
# 	iter:    30/   34 | loss: 0.020
# epoch 57 time: 0:00:00.263256 s
# train loss: 0.050 | val loss: 0.865 | test loss: 1.694
# EarlyStopping counter: 17 out of 20
# epoch: 58
# 	iter:     0/   34 | loss: 0.062
# 	iter:    10/   34 | loss: 0.080
# 	iter:    20/   34 | loss: 0.054
# 	iter:    30/   34 | loss: 0.066
# epoch 58 time: 0:00:00.232838 s
# train loss: 0.064 | val loss: 0.720 | test loss: 1.603
# EarlyStopping counter: 18 out of 20
# epoch: 59
# 	iter:     0/   34 | loss: 0.045
# 	iter:    10/   34 | loss: 0.028
# 	iter:    20/   34 | loss: 0.122
# 	iter:    30/   34 | loss: 0.114
# epoch 59 time: 0:00:00.275882 s
# train loss: 0.060 | val loss: 0.858 | test loss: 1.635
# EarlyStopping counter: 19 out of 20
# epoch: 60
# 	iter:     0/   34 | loss: 0.042
# 	iter:    10/   34 | loss: 0.138
# 	iter:    20/   34 | loss: 0.051
# 	iter:    30/   34 | loss: 0.040
# epoch 60 time: 0:00:00.224827 s
# train loss: 0.087 | val loss: 0.849 | test loss: 1.503
# EarlyStopping counter: 20 out of 20
# early stopping!
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# epoch: 1
# 	iter:     0/   34 | loss: 1.545
# 	iter:    10/   34 | loss: 0.553
# 	iter:    20/   34 | loss: 0.524
# 	iter:    30/   34 | loss: 0.260
# epoch 1 time: 0:00:00.282221 s
# train loss: 0.680 | val loss: 0.891 | test loss: 1.201
# validation loss decreased (inf --> 0.891)
# saving model
# epoch: 2
# 	iter:     0/   34 | loss: 0.305
# 	iter:    10/   34 | loss: 0.357
# 	iter:    20/   34 | loss: 0.063
# 	iter:    30/   34 | loss: 0.252
# epoch 2 time: 0:00:00.250054 s
# train loss: 0.292 | val loss: 0.546 | test loss: 1.071
# validation loss decreased (0.891 --> 0.546)
# saving model
# epoch: 3
# 	iter:     0/   34 | loss: 0.424
# 	iter:    10/   34 | loss: 0.297
# 	iter:    20/   34 | loss: 0.057
# 	iter:    30/   34 | loss: 0.041
# epoch 3 time: 0:00:00.297562 s
# train loss: 0.240 | val loss: 0.539 | test loss: 1.181
# validation loss decreased (0.546 --> 0.539)
# saving model
# epoch: 4
# 	iter:     0/   34 | loss: 0.101
# 	iter:    10/   34 | loss: 0.529
# 	iter:    20/   34 | loss: 0.118
# 	iter:    30/   34 | loss: 0.057
# epoch 4 time: 0:00:00.230859 s
# train loss: 0.214 | val loss: 0.523 | test loss: 1.616
# validation loss decreased (0.539 --> 0.523)
# saving model
# epoch: 5
# 	iter:     0/   34 | loss: 0.131
# 	iter:    10/   34 | loss: 0.014
# 	iter:    20/   34 | loss: 0.093
# 	iter:    30/   34 | loss: 0.392
# epoch 5 time: 0:00:00.233382 s
# train loss: 0.194 | val loss: 0.466 | test loss: 1.785
# validation loss decreased (0.523 --> 0.466)
# saving model
# epoch: 6
# 	iter:     0/   34 | loss: 0.192
# 	iter:    10/   34 | loss: 0.085
# 	iter:    20/   34 | loss: 0.102
# 	iter:    30/   34 | loss: 0.112
# epoch 6 time: 0:00:00.229027 s
# train loss: 0.218 | val loss: 0.577 | test loss: 1.786
# EarlyStopping counter: 1 out of 20
# epoch: 7
# 	iter:     0/   34 | loss: 0.138
# 	iter:    10/   34 | loss: 0.126
# 	iter:    20/   34 | loss: 0.094
# 	iter:    30/   34 | loss: 0.098
# epoch 7 time: 0:00:00.216662 s
# train loss: 0.208 | val loss: 0.531 | test loss: 1.629
# EarlyStopping counter: 2 out of 20
# epoch: 8
# 	iter:     0/   34 | loss: 0.500
# 	iter:    10/   34 | loss: 0.079
# 	iter:    20/   34 | loss: 0.069
# 	iter:    30/   34 | loss: 0.153
# epoch 8 time: 0:00:00.256805 s
# train loss: 0.192 | val loss: 0.532 | test loss: 1.452
# EarlyStopping counter: 3 out of 20
# epoch: 9
# 	iter:     0/   34 | loss: 0.091
# 	iter:    10/   34 | loss: 0.493
# 	iter:    20/   34 | loss: 0.051
# 	iter:    30/   34 | loss: 0.478
# epoch 9 time: 0:00:00.267604 s
# train loss: 0.168 | val loss: 0.531 | test loss: 1.711
# EarlyStopping counter: 4 out of 20
# epoch: 10
# 	iter:     0/   34 | loss: 0.112
# 	iter:    10/   34 | loss: 0.466
# 	iter:    20/   34 | loss: 0.130
# 	iter:    30/   34 | loss: 0.415
# ...
# EarlyStopping counter: 13 out of 20
# epoch: 16
# 	iter:     0/   34 | loss: 0.113
# 	iter:    10/   34 | loss: 0.764
# 	iter:    20/   34 | loss: 0.338
# 	iter:    30/   34 | loss: 0.272
# epoch 16 time: 0:00:00.310694 s
# train loss: 0.200 | val loss: 0.925 | test loss: 2.434
# EarlyStopping counter: 14 out of 20
# epoch: 17
# 	iter:     0/   34 | loss: 0.060
# 	iter:    10/   34 | loss: 0.450
# 	iter:    20/   34 | loss: 0.028
# 	iter:    30/   34 | loss: 0.042
# epoch 17 time: 0:00:00.316010 s
# train loss: 0.143 | val loss: 1.123 | test loss: 1.938
# EarlyStopping counter: 15 out of 20
# epoch: 18
# 	iter:     0/   34 | loss: 0.053
# 	iter:    10/   34 | loss: 0.017
# 	iter:    20/   34 | loss: 0.185
# 	iter:    30/   34 | loss: 0.096
# epoch 18 time: 0:00:00.291389 s
# train loss: 0.159 | val loss: 1.126 | test loss: 2.080
# EarlyStopping counter: 16 out of 20
# epoch: 19
# 	iter:     0/   34 | loss: 0.021
# 	iter:    10/   34 | loss: 0.049
# 	iter:    20/   34 | loss: 0.246
# 	iter:    30/   34 | loss: 0.050
# epoch 19 time: 0:00:00.289347 s
# train loss: 0.132 | val loss: 0.963 | test loss: 2.142
# EarlyStopping counter: 17 out of 20
# epoch: 20
# 	iter:     0/   34 | loss: 0.465
# 	iter:    10/   34 | loss: 0.073
# 	iter:    20/   34 | loss: 0.276
# 	iter:    30/   34 | loss: 0.051
# epoch 20 time: 0:00:00.250242 s
# train loss: 0.140 | val loss: 1.051 | test loss: 2.082
# EarlyStopping counter: 18 out of 20
# epoch: 21
# 	iter:     0/   34 | loss: 0.075
# 	iter:    10/   34 | loss: 0.069
# 	iter:    20/   34 | loss: 0.031
# 	iter:    30/   34 | loss: 0.045
# epoch 21 time: 0:00:00.290947 s
# train loss: 0.134 | val loss: 1.025 | test loss: 1.925
# EarlyStopping counter: 19 out of 20
# epoch: 22
# 	iter:     0/   34 | loss: 0.029
# 	iter:    10/   34 | loss: 0.394
# 	iter:    20/   34 | loss: 0.036
# 	iter:    30/   34 | loss: 0.106
# epoch 22 time: 0:00:00.308984 s
# train loss: 0.133 | val loss: 0.906 | test loss: 2.087
# EarlyStopping counter: 20 out of 20
# early stopping!
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# epoch: 1
# 	iter:     0/   34 | loss: 1.480
# 	iter:    10/   34 | loss: 0.582
# 	iter:    20/   34 | loss: 0.083
# 	iter:    30/   34 | loss: 0.038
# epoch 1 time: 0:00:00.255678 s
# train loss: 0.511 | val loss: 0.674 | test loss: 0.959
# validation loss decreased (inf --> 0.674)
# saving model
# epoch: 2
# 	iter:     0/   34 | loss: 0.089
# 	iter:    10/   34 | loss: 0.037
# 	iter:    20/   34 | loss: 0.065
# 	iter:    30/   34 | loss: 0.578
# epoch 2 time: 0:00:00.222372 s
# train loss: 0.200 | val loss: 0.660 | test loss: 0.944
# validation loss decreased (0.674 --> 0.660)
# saving model
# epoch: 3
# 	iter:     0/   34 | loss: 0.144
# 	iter:    10/   34 | loss: 0.061
# 	iter:    20/   34 | loss: 0.187
# 	iter:    30/   34 | loss: 0.058
# epoch 3 time: 0:00:00.218085 s
# train loss: 0.182 | val loss: 0.681 | test loss: 0.962
# EarlyStopping counter: 1 out of 20
# epoch: 4
# 	iter:     0/   34 | loss: 0.193
# 	iter:    10/   34 | loss: 0.475
# 	iter:    20/   34 | loss: 0.122
# 	iter:    30/   34 | loss: 0.096
# epoch 4 time: 0:00:00.296676 s
# train loss: 0.186 | val loss: 0.721 | test loss: 1.058
# EarlyStopping counter: 2 out of 20
# epoch: 5
# 	iter:     0/   34 | loss: 0.105
# 	iter:    10/   34 | loss: 0.200
# 	iter:    20/   34 | loss: 0.040
# 	iter:    30/   34 | loss: 0.087
# epoch 5 time: 0:00:00.235314 s
# train loss: 0.175 | val loss: 0.777 | test loss: 1.119
# EarlyStopping counter: 3 out of 20
# epoch: 6
# 	iter:     0/   34 | loss: 0.116
# 	iter:    10/   34 | loss: 0.012
# 	iter:    20/   34 | loss: 0.082
# 	iter:    30/   34 | loss: 0.139
# epoch 6 time: 0:00:00.283412 s
# train loss: 0.177 | val loss: 0.853 | test loss: 1.153
# EarlyStopping counter: 4 out of 20
# epoch: 7
# 	iter:     0/   34 | loss: 0.095
# 	iter:    10/   34 | loss: 0.049
# 	iter:    20/   34 | loss: 0.105
# 	iter:    30/   34 | loss: 0.116
# epoch 7 time: 0:00:00.269337 s
# train loss: 0.190 | val loss: 0.785 | test loss: 1.086
# EarlyStopping counter: 5 out of 20
# epoch: 8
# 	iter:     0/   34 | loss: 0.479
# 	iter:    10/   34 | loss: 0.223
# 	iter:    20/   34 | loss: 0.143
# 	iter:    30/   34 | loss: 0.103
# epoch 8 time: 0:00:00.246738 s
# train loss: 0.187 | val loss: 0.704 | test loss: 0.947
# EarlyStopping counter: 6 out of 20
# epoch: 9
# 	iter:     0/   34 | loss: 0.053
# 	iter:    10/   34 | loss: 0.450
# 	iter:    20/   34 | loss: 0.035
# 	iter:    30/   34 | loss: 0.407
# epoch 9 time: 0:00:00.233980 s
# train loss: 0.148 | val loss: 0.805 | test loss: 1.060
# EarlyStopping counter: 7 out of 20
# epoch: 10
# 	iter:     0/   34 | loss: 0.098
# 	iter:    10/   34 | loss: 0.312
# 	iter:    20/   34 | loss: 0.097
# 	iter:    30/   34 | loss: 0.400
# epoch 10 time: 0:00:00.256698 s
# train loss: 0.155 | val loss: 0.732 | test loss: 0.972
# EarlyStopping counter: 8 out of 20
# epoch: 11
# 	iter:     0/   34 | loss: 0.054
# 	iter:    10/   34 | loss: 0.136
# 	iter:    20/   34 | loss: 0.036
# 	iter:    30/   34 | loss: 0.036
# epoch 11 time: 0:00:00.270410 s
# train loss: 0.167 | val loss: 0.879 | test loss: 1.167
# EarlyStopping counter: 9 out of 20
# epoch: 12
# 	iter:     0/   34 | loss: 0.123
# 	iter:    10/   34 | loss: 0.055
# 	iter:    20/   34 | loss: 0.032
# 	iter:    30/   34 | loss: 0.419
# epoch 12 time: 0:00:00.266343 s
# train loss: 0.151 | val loss: 0.756 | test loss: 1.057
# EarlyStopping counter: 10 out of 20
# epoch: 13
# 	iter:     0/   34 | loss: 0.186
# 	iter:    10/   34 | loss: 0.383
# 	iter:    20/   34 | loss: 0.049
# 	iter:    30/   34 | loss: 0.414
# epoch 13 time: 0:00:00.314443 s
# train loss: 0.139 | val loss: 0.867 | test loss: 1.199
# EarlyStopping counter: 11 out of 20
# epoch: 14
# 	iter:     0/   34 | loss: 0.047
# 	iter:    10/   34 | loss: 0.424
# 	iter:    20/   34 | loss: 0.358
# 	iter:    30/   34 | loss: 0.048
# epoch 14 time: 0:00:00.279786 s
# train loss: 0.140 | val loss: 0.751 | test loss: 1.051
# EarlyStopping counter: 12 out of 20
# epoch: 15
# 	iter:     0/   34 | loss: 0.080
# 	iter:    10/   34 | loss: 0.043
# 	iter:    20/   34 | loss: 0.074
# 	iter:    30/   34 | loss: 0.020
# epoch 15 time: 0:00:00.264181 s
# train loss: 0.124 | val loss: 0.936 | test loss: 1.189
# EarlyStopping counter: 13 out of 20
# epoch: 16
# 	iter:     0/   34 | loss: 0.103
# 	iter:    10/   34 | loss: 0.234
# 	iter:    20/   34 | loss: 0.371
# 	iter:    30/   34 | loss: 0.338
# epoch 16 time: 0:00:00.249959 s
# train loss: 0.148 | val loss: 0.774 | test loss: 1.029
# EarlyStopping counter: 14 out of 20
# epoch: 17
# 	iter:     0/   34 | loss: 0.031
# 	iter:    10/   34 | loss: 0.436
# 	iter:    20/   34 | loss: 0.062
# 	iter:    30/   34 | loss: 0.055
# epoch 17 time: 0:00:00.259439 s
# train loss: 0.133 | val loss: 0.878 | test loss: 1.158
# EarlyStopping counter: 15 out of 20
# epoch: 18
# 	iter:     0/   34 | loss: 0.055
# 	iter:    10/   34 | loss: 0.049
# 	iter:    20/   34 | loss: 0.102
# 	iter:    30/   34 | loss: 0.042
# epoch 18 time: 0:00:00.281604 s
# train loss: 0.119 | val loss: 0.876 | test loss: 1.223
# EarlyStopping counter: 16 out of 20
# epoch: 19
# 	iter:     0/   34 | loss: 0.084
# 	iter:    10/   34 | loss: 0.010
# 	iter:    20/   34 | loss: 0.040
# 	iter:    30/   34 | loss: 0.083
# epoch 19 time: 0:00:00.255633 s
# train loss: 0.107 | val loss: 0.788 | test loss: 1.052
# EarlyStopping counter: 17 out of 20
# epoch: 20
# 	iter:     0/   34 | loss: 0.199
# 	iter:    10/   34 | loss: 0.063
# 	iter:    20/   34 | loss: 0.287
# 	iter:    30/   34 | loss: 0.074
# epoch 20 time: 0:00:00.250822 s
# train loss: 0.098 | val loss: 0.859 | test loss: 1.144
# EarlyStopping counter: 18 out of 20
# epoch: 21
# 	iter:     0/   34 | loss: 0.040
# 	iter:    10/   34 | loss: 0.123
# 	iter:    20/   34 | loss: 0.113
# 	iter:    30/   34 | loss: 0.030
# epoch 21 time: 0:00:00.250304 s
# train loss: 0.135 | val loss: 0.879 | test loss: 1.190
# EarlyStopping counter: 19 out of 20
# epoch: 22
# 	iter:     0/   34 | loss: 0.079
# 	iter:    10/   34 | loss: 0.153
# 	iter:    20/   34 | loss: 0.013
# 	iter:    30/   34 | loss: 0.017
# epoch 22 time: 0:00:00.247807 s
# train loss: 0.100 | val loss: 0.822 | test loss: 1.138
# EarlyStopping counter: 20 out of 20
# early stopping!
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# epoch: 1
# 	iter:     0/   34 | loss: 1.515
# 	iter:    10/   34 | loss: 0.525
# 	iter:    20/   34 | loss: 0.492
# 	iter:    30/   34 | loss: 0.286
# epoch 1 time: 0:00:00.233837 s
# train loss: 0.650 | val loss: 1.123 | test loss: 1.902
# validation loss decreased (inf --> 1.123)
# saving model
# epoch: 2
# 	iter:     0/   34 | loss: 0.214
# 	iter:    10/   34 | loss: 0.143
# 	iter:    20/   34 | loss: 0.070
# 	iter:    30/   34 | loss: 0.674
# epoch 2 time: 0:00:00.295431 s
# train loss: 0.226 | val loss: 1.369 | test loss: 1.829
# EarlyStopping counter: 1 out of 20
# epoch: 3
# 	iter:     0/   34 | loss: 0.109
# 	iter:    10/   34 | loss: 0.148
# 	iter:    20/   34 | loss: 0.074
# 	iter:    30/   34 | loss: 0.048
# epoch 3 time: 0:00:00.273827 s
# train loss: 0.220 | val loss: 1.203 | test loss: 1.839
# EarlyStopping counter: 2 out of 20
# epoch: 4
# 	iter:     0/   34 | loss: 0.114
# 	iter:    10/   34 | loss: 0.534
# 	iter:    20/   34 | loss: 0.133
# 	iter:    30/   34 | loss: 0.082
# epoch 4 time: 0:00:00.222090 s
# train loss: 0.206 | val loss: 1.154 | test loss: 1.886
# EarlyStopping counter: 3 out of 20
# epoch: 5
# 	iter:     0/   34 | loss: 0.098
# 	iter:    10/   34 | loss: 0.041
# 	iter:    20/   34 | loss: 0.083
# 	iter:    30/   34 | loss: 0.166
# epoch 5 time: 0:00:00.269741 s
# train loss: 0.196 | val loss: 1.210 | test loss: 2.125
# EarlyStopping counter: 4 out of 20
# epoch: 6
# 	iter:     0/   34 | loss: 0.297
# 	iter:    10/   34 | loss: 0.057
# 	iter:    20/   34 | loss: 0.187
# 	iter:    30/   34 | loss: 0.090
# epoch 6 time: 0:00:00.232229 s
# train loss: 0.216 | val loss: 1.483 | test loss: 2.050
# EarlyStopping counter: 5 out of 20
# epoch: 7
# 	iter:     0/   34 | loss: 0.084
# 	iter:    10/   34 | loss: 0.083
# 	iter:    20/   34 | loss: 0.047
# 	iter:    30/   34 | loss: 0.049
# epoch 7 time: 0:00:00.267525 s
# train loss: 0.217 | val loss: 1.378 | test loss: 2.004
# EarlyStopping counter: 6 out of 20
# epoch: 8
# 	iter:     0/   34 | loss: 0.514
# 	iter:    10/   34 | loss: 0.097
# 	iter:    20/   34 | loss: 0.113
# 	iter:    30/   34 | loss: 0.236
# epoch 8 time: 0:00:00.246186 s
# train loss: 0.209 | val loss: 1.001 | test loss: 1.616
# validation loss decreased (1.123 --> 1.001)
# saving model
# epoch: 9
# 	iter:     0/   34 | loss: 0.180
# 	iter:    10/   34 | loss: 0.509
# 	iter:    20/   34 | loss: 0.114
# 	iter:    30/   34 | loss: 0.499
# epoch 9 time: 0:00:00.276720 s
# train loss: 0.195 | val loss: 1.200 | test loss: 1.990
# EarlyStopping counter: 1 out of 20
# epoch: 10
# 	iter:     0/   34 | loss: 0.132
# 	iter:    10/   34 | loss: 0.326
# 	iter:    20/   34 | loss: 0.139
# 	iter:    30/   34 | loss: 0.481
# epoch 10 time: 0:00:00.262649 s
# train loss: 0.205 | val loss: 1.262 | test loss: 1.897
# EarlyStopping counter: 2 out of 20
# epoch: 11
# 	iter:     0/   34 | loss: 0.075
# 	iter:    10/   34 | loss: 0.108
# 	iter:    20/   34 | loss: 0.049
# 	iter:    30/   34 | loss: 0.047
# epoch 11 time: 0:00:00.231400 s
# train loss: 0.184 | val loss: 1.682 | test loss: 2.027
# EarlyStopping counter: 3 out of 20
# epoch: 12
# 	iter:     0/   34 | loss: 0.301
# 	iter:    10/   34 | loss: 0.219
# 	iter:    20/   34 | loss: 0.032
# 	iter:    30/   34 | loss: 0.511
# epoch 12 time: 0:00:00.250106 s
# train loss: 0.180 | val loss: 1.414 | test loss: 1.968
# EarlyStopping counter: 4 out of 20
# epoch: 13
# 	iter:     0/   34 | loss: 0.129
# 	iter:    10/   34 | loss: 0.452
# 	iter:    20/   34 | loss: 0.005
# 	iter:    30/   34 | loss: 0.532
# epoch 13 time: 0:00:00.234188 s
# train loss: 0.184 | val loss: 1.365 | test loss: 1.970
# EarlyStopping counter: 5 out of 20
# epoch: 14
# 	iter:     0/   34 | loss: 0.262
# 	iter:    10/   34 | loss: 0.487
# 	iter:    20/   34 | loss: 0.443
# 	iter:    30/   34 | loss: 0.072
# epoch 14 time: 0:00:00.223657 s
# train loss: 0.177 | val loss: 1.240 | test loss: 1.874
# EarlyStopping counter: 6 out of 20
# epoch: 15
# 	iter:     0/   34 | loss: 0.090
# 	iter:    10/   34 | loss: 0.024
# 	iter:    20/   34 | loss: 0.065
# 	iter:    30/   34 | loss: 0.093
# epoch 15 time: 0:00:00.396265 s
# train loss: 0.166 | val loss: 1.338 | test loss: 1.739
# EarlyStopping counter: 7 out of 20
# epoch: 16
# 	iter:     0/   34 | loss: 0.052
# 	iter:    10/   34 | loss: 0.160
# 	iter:    20/   34 | loss: 0.519
# 	iter:    30/   34 | loss: 0.474
# epoch 16 time: 0:00:00.320978 s
# train loss: 0.184 | val loss: 1.399 | test loss: 1.864
# EarlyStopping counter: 8 out of 20
# epoch: 17
# 	iter:     0/   34 | loss: 0.028
# 	iter:    10/   34 | loss: 0.505
# 	iter:    20/   34 | loss: 0.060
# 	iter:    30/   34 | loss: 0.027
# epoch 17 time: 0:00:00.277686 s
# train loss: 0.149 | val loss: 1.344 | test loss: 1.869
# EarlyStopping counter: 9 out of 20
# epoch: 18
# 	iter:     0/   34 | loss: 0.030
# 	iter:    10/   34 | loss: 0.049
# 	iter:    20/   34 | loss: 0.101
# 	iter:    30/   34 | loss: 0.140
# epoch 18 time: 0:00:00.266315 s
# train loss: 0.177 | val loss: 1.450 | test loss: 1.917
# EarlyStopping counter: 10 out of 20
# epoch: 19
# 	iter:     0/   34 | loss: 0.032
# 	iter:    10/   34 | loss: 0.044
# 	iter:    20/   34 | loss: 0.043
# 	iter:    30/   34 | loss: 0.137
# epoch 19 time: 0:00:00.253048 s
# train loss: 0.149 | val loss: 1.245 | test loss: 1.812
# EarlyStopping counter: 11 out of 20
# epoch: 20
# 	iter:     0/   34 | loss: 0.128
# 	iter:    10/   34 | loss: 0.110
# 	iter:    20/   34 | loss: 0.492
# 	iter:    30/   34 | loss: 0.107
# epoch 20 time: 0:00:00.268134 s
# train loss: 0.185 | val loss: 1.741 | test loss: 2.059
# EarlyStopping counter: 12 out of 20
# epoch: 21
# 	iter:     0/   34 | loss: 0.129
# 	iter:    10/   34 | loss: 0.161
# 	iter:    20/   34 | loss: 0.121
# 	iter:    30/   34 | loss: 0.093
# epoch 21 time: 0:00:00.241768 s
# train loss: 0.174 | val loss: 1.189 | test loss: 1.958
# EarlyStopping counter: 13 out of 20
# epoch: 22
# 	iter:     0/   34 | loss: 0.064
# 	iter:    10/   34 | loss: 0.032
# 	iter:    20/   34 | loss: 0.094
# 	iter:    30/   34 | loss: 0.087
# epoch 22 time: 0:00:00.239206 s
# train loss: 0.182 | val loss: 1.108 | test loss: 1.959
# EarlyStopping counter: 14 out of 20
# epoch: 23
# 	iter:     0/   34 | loss: 0.458
# 	iter:    10/   34 | loss: 0.040
# 	iter:    20/   34 | loss: 0.024
# 	iter:    30/   34 | loss: 0.064
# epoch 23 time: 0:00:00.224475 s
# train loss: 0.158 | val loss: 1.228 | test loss: 1.965
# EarlyStopping counter: 15 out of 20
# epoch: 24
# 	iter:     0/   34 | loss: 0.104
# 	iter:    10/   34 | loss: 0.036
# 	iter:    20/   34 | loss: 0.018
# 	iter:    30/   34 | loss: 0.030
# epoch 24 time: 0:00:00.237185 s
# train loss: 0.158 | val loss: 1.144 | test loss: 1.971
# EarlyStopping counter: 16 out of 20
# epoch: 25
# 	iter:     0/   34 | loss: 0.096
# 	iter:    10/   34 | loss: 0.471
# 	iter:    20/   34 | loss: 0.072
# 	iter:    30/   34 | loss: 0.509
# epoch 25 time: 0:00:00.220405 s
# train loss: 0.146 | val loss: 1.149 | test loss: 1.959
# EarlyStopping counter: 17 out of 20
# epoch: 26
# 	iter:     0/   34 | loss: 0.014
# 	iter:    10/   34 | loss: 0.051
# 	iter:    20/   34 | loss: 0.398
# 	iter:    30/   34 | loss: 0.052
# epoch 26 time: 0:00:00.221689 s
# train loss: 0.145 | val loss: 1.077 | test loss: 2.025
# EarlyStopping counter: 18 out of 20
# epoch: 27
# 	iter:     0/   34 | loss: 0.085
# 	iter:    10/   34 | loss: 0.385
# 	iter:    20/   34 | loss: 0.090
# 	iter:    30/   34 | loss: 0.429
# epoch 27 time: 0:00:00.235090 s
# train loss: 0.161 | val loss: 1.112 | test loss: 1.961
# EarlyStopping counter: 19 out of 20
# epoch: 28
# 	iter:     0/   34 | loss: 0.031
# 	iter:    10/   34 | loss: 0.023
# 	iter:    20/   34 | loss: 0.027
# 	iter:    30/   34 | loss: 0.099
# epoch 28 time: 0:00:00.221249 s
# train loss: 0.144 | val loss: 1.177 | test loss: 2.047
# EarlyStopping counter: 20 out of 20
# early stopping!
# X does not have valid feature names, but StandardScaler was fitted with feature names
